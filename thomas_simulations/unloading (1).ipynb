# %%
import matplotlib.pyplot as plt
import numpy as np
import os, sys, alive_progress

from quantum_electron.electron_counter import FullModel, make_potential, find_minimum_location
from quantum_electron.schrodinger_solver import QuantumAnalysis
from quantum_electron.utils import xy2r, r2xy, crop_potential, find_nearest,  density_from_positions, select_outer_electrons, find_minimum_location

from zeroheliumkit.src.importing import Reader_DXF
from zeroheliumkit.fem import FieldAnalyzer
from zeroheliumkit.src.settings import *
import matplotlib.animation as animation

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

plot_config = {"anchors": CYAN,
               "0": BLUE,
               "EBEAMLITHO_GUARDS": ORANGE,
               "EBEAMLITHO_SMALLPADS": RED,
               "Pillar0": GREEN}
import zeroheliumkit 
from scipy.constants import elementary_charge as qe, epsilon_0 as eps0, electron_mass as me, Boltzmann as kB
from matplotlib import patheffects as pe
import random

# %% [markdown]
# ## Download the potential

# %%
dirname = 'sim_test2/'
device = zeroheliumkit.GeomCollection(layers=Reader_DXF(r"./sim2/sample_resevoir_10x10_no_bond_lines.dxf").geometries)
device.quickplot(plot_config)
trap = FieldAnalyzer((dirname+'phi_xy.txt', 'dot', '2Dmap'))
# Out:
# ./sim2/sample_resevoir_10x10_no_bond_lines.dxf // Layers : dict_keys(['EBEAMLITHO_SMALLPADS', '0', 'EBEAMLITHO_GUARDS'])

# %%
print(f"Input data dx = {np.diff(trap.dot['xlist'])[0] * 1e3:.1f} nm")
print(f"Input data dy = {np.diff(trap.dot['ylist'])[0] * 1e3:.1f} nm")
# Out:
# Input data dx = 20.0 nm
# Input data dy = 20.0 nm

# %% [markdown]
# ## Choose the voltages
# typical charge noise 100 uV (GaAs @Delft) 230 uV(Si @Delft) 70 uV (best Si) 8 uV (best GaAs)
#
# These values are dominated by the devices themselves, not from the electronics.

# %%
from quantum_electron.utils import crop_potential

voltages = {
    'half_donut_top':0.5,
    'half_donut_bottom':0.5,
    'gate_top':0.2,
    'gate_bottom':0.2,
    'reservoir':0.7,
    'center':0.6,
    'guard':-0.000,
}

for electrode in trap.dot.keys():
    if electrode == 'xlist' or electrode == 'ylist':
        break
    new_x, new_y, new_U = crop_potential(x=trap.dot['xlist'], y=trap.dot['ylist'], U=trap.dot[electrode],
                                         xrange=(-5, 2), yrange=(-4,4))

    trap.dot[electrode] = new_U

trap.dot['xlist'] = new_x
trap.dot['ylist'] = new_y

# %%
fig, ax = plt.subplots()
fm = FullModel(trap.dot, voltages)
fm.plot_potential_energy(ax=ax, coor=[0,0], dxdy=(10, 8))
ax.set_xlim(-5, 2)
# Out:
# (-5.0, 2.0)

# %%
qa = QuantumAnalysis(trap.dot, voltages)

qa.plot_potential_energy(coor=(0, 0), dxdy=(3, 3))

# %%
qa = QuantumAnalysis(trap.dot, voltages)

 #Returns the frequencies of the first N=6 eigenmodes for a single electron trapped in a potential. 
# if qa.solve_system has not been   run before, then this line will start by solving the system 
# the solution window of the Schrodinger equation will be of size (dxdy[0], dxdy[1]) centered on (coor[0], 0). The y coordinate of the center is always 0 and cannot be changed.
#coor:  Defaults to [0,0].
#dxdy : Defaults to [1, 2].
# changing this perimeter will change the positions of the wavefunctions and the energy splitting
# by setting axes_zoom to a non zero value, it sets a ylim and xlim in the plot around the center of mass of the wavefunction. 

single_electron_frequencies = qa.get_quantum_spectrum( axes_zoom=0.2,plot_wavefunctions=True, n_x=401, n_y=401)
# here the energy splitting between first and excited is higher than with the same script on box because the S. equation is solved on a larger interval
# Out:
# max_ysol:1.0
# y_com_max:0.09947000698316173
# max_ysol:1.0
# y_com_max:0.09946980895236864
# max_ysol:1.0
# y_com_max:0.09941874548318222
# max_ysol:1.0
# y_com_max:0.09943958190564556
# max_ysol:1.0
# y_com_max:0.09943943885963516
# max_ysol:1.0
# y_com_max:0.09945515378814662

# %% [markdown]
# ## Test voltage configuration

# %% [markdown]
# ### Calculate electrons equilibrium positions

# %%
import numpy as np
import matplotlib.pyplot as plt

# Conversion en float64 des bornes
x_min = np.float64(np.min(trap.dot['xlist']) * 1e-6)
x_max = np.float64(np.max(trap.dot['xlist']) * 1e-6)
y_min = np.float64(np.min(trap.dot['ylist']) * 1e-6)
y_max = np.float64(np.max(trap.dot['ylist']) * 1e-6)

voltages = {
    'half_donut_top':0.5,
    'half_donut_bottom':0,
    'gate_top':0.3,
    'gate_bottom':0.0,
    'reservoir':-0.05,
    'center':0,
    'guard':0.000,
}

options = { "include_screening" : False, # Include screening of electron-electron interactions due to thin film.
           "screening_length" : np.inf, # Typically helium thickness.
           "potential_smoothing" : 1e-5, # Numerical smoothing of the splines (gets rid of some noise, can introduce artifacts)
           "remove_unbound_electrons" : False, # Removes electrons if they shot outside the solution box.
           "remove_bounds" : None, # Sets which electrons should be removed if above is True.
           "trap_annealing_steps" : [0.1] * 10, # List of annealing temperatures, length determines the number of steps
           "max_x_displacement" : 0.1e-6, # Maximum x-displacement of solved electron positions during annealing.
           "max_y_displacement" : 0.1e-6} # Maximum y-displacement of solved electron positions during annealing.


plot_initial_condition = True
convergence_method = 'Physical gradient descent'
Nmax = 5
energies = np.zeros(Nmax-1, dtype=np.float64)
max_force = []


# Dimensionless rescaling
# -------------------------
# Base units (SI → dimensionless)
L0 = 1e-6                      # 1 μm in meters
E0 = qe                        # 1 eV in joules
M0 = me                        # electron mass in kg
Q0 = qe                        # elementary charge in C
T0 = L0 * np.sqrt(M0/E0)      # derived time unit

# Convert your physical timestep into dimensionless dt
dt_phys = 1e-13                # your original dt in seconds
dt = np.float64(dt_phys / T0)  # dimensionless

# Now redefine your usual Verlet coefficients in *this* dt
gamma    = np.float64(-0.01) / dt
prefactor= np.float64(1.0) / (1.0/dt**2 - gamma/dt)
A        = np.float64(2.0/dt**2 - gamma/dt)
B        = np.float64(1.0/dt**2)

max_timesteps = 500000# Maximum number of timesteps for the convergence method


for N in [5]:
    f = FullModel(trap.dot, voltages, **options)
    f.remove_unbound_electrons = False

    initial_condition = f.generate_initial_condition(N, center=[0, 0], radius=np.float64(0.1e-6))
    init_x, init_y = r2xy(initial_condition)

    if convergence_method == 'L-BFGS-B':
        f.trap_annealing_steps = [0.5] * 30
        res = f.get_electron_positions(n_electrons=N, electron_initial_positions=initial_condition,
                                       verbose=False, gradient_tolerance=1e-9, ftol=1e-300)
        equilibrium_positions = res['x']

    elif convergence_method == 'Physical gradient descent':
        # Convert the *physical* positions into primed coords:
        r_old = (initial_condition / L0).astype(np.float64)
        r_cur = r_old.copy()
        j = 2

        while True:
            # 1) compute physical gradient at r_phys = r_cur*L0
            grad_phys = f.grad_total(r_cur * L0)          # in V/m
            # 2) F_phys = -qe * grad_phys (J/m), convert to dimensionless:
            F = -(qe * grad_phys) * (L0/E0)     # dimensionless
            max_force.append(np.max(np.abs(F)))

            # 3) Verlet‐damped update (dimensionless)
            r_next = prefactor * (F + r_cur * A - r_old * B)

            # 4) Remove electrons out of domain in primed coords
            x_next = r_next[::2];  y_next = r_next[1::2]
            inside = np.logical_and.reduce((
                x_next*L0 >= x_min, x_next*L0 <= x_max,
                y_next*L0 >= y_min, y_next*L0 <= y_max
            ))


            r_next_filtered    = np.empty((2*np.sum(inside)), dtype=np.float64)
            r_current_filtered = np.empty((2*np.sum(inside)), dtype=np.float64)

            r_next_filtered[::2]    = x_next[inside]
            r_next_filtered[1::2]   = y_next[inside]
            r_current_filtered[::2] = r_cur[::2][inside]
            r_current_filtered[1::2]= r_cur[1::2][inside]

            # rotate for next pass
            r_old, r_cur = r_current_filtered, r_next_filtered
            j += 1

            if len(r_cur)==0:
                print(f'During the convergence, no electrons left after {j} steps.')
                break
            
            # 5) Check convergence in dimensionless force
            if np.max(np.abs(F)) < 1e-12:
                print(f'Converged after {j} steps.')
                r_cur = r_next_filtered
                break

            if j >= max_timesteps:
                print(f'Not converged after {max_timesteps} steps.')
                break

        # Convert *back* to physical coordinates (meters)
        equilibrium_positions = (r_cur * L0)
        print(max_force[-1])



    print(f'The distance between the last two iterations is {np.linalg.norm(r_cur - r_old) * 1e6:.2f} um.')

    final_x, final_y = r2xy(equilibrium_positions)
    number_electron = f.count_electrons_in_dot(equilibrium_positions,
                                               trap_bounds_x=(-2e-6, 2e-6),
                                               trap_bounds_y=(-2e-6, 2e-6))
    print(f'There are {number_electron} electrons in the dot.')

    fig, ax = plt.subplots()
    f.plot_potential_energy(coor=[0, 0], dxdy=(10, 8), ax=ax)
    res = {'x': equilibrium_positions}
    f.plot_electron_positions(res)
    ax.set_xlim(-5, 2)

    if plot_initial_condition:
        plt.plot(init_x * 1e6, init_y * 1e6, 'or', ms=3)
# Out:
# Converged after 5433 steps.
# 9.757550287758931e-13
# The distance between the last two iterations is 0.00 um.
# There are 5 electrons in the dot.

# %%
fig, ax = plt.subplots()
ax.scatter(range(len(max_force)), max_force, s=1, c='k', label='Norm of the force')
ax.set_xlabel('Time step')
ax.set_ylabel('Norm of gradient')
# ax.set_ylim(0, 3e-13)
ax.legend()

print(f"Electron positions: x_min={x_min:.2e}, x_max={x_max:.2e}, y_min={y_min:.2e}, y_max={y_max:.2e}")
if np.any(final_x < x_min) or np.any(final_x > x_max) or np.any(final_y < y_min) or np.any(final_y > y_max):
    print("Electron outside potential grid!")

print(np.finfo(np.float64).eps)
# Out:
# Electron positions: x_min=-5.00e-06, x_max=1.98e-06, y_min=-4.00e-06, y_max=3.98e-06
# 2.220446049250313e-16

# %% [markdown]
# ### Setup EOM

# %%
Vrms = 140e-9
f0 = 0.8e9

Z = 2 / 1.055e-34 * (Vrms / (2 * np.pi * f0)) ** 2

resonator_dict = {"f0" : f0, # Resonance frequency for the resonator (only used for solving motional frequencies)
                  "Z0" : Z} # Resonator impedance (only used for solving motional frequencies)

# %%
f.set_rf_interpolator(rf_electrode_labels=['gate_top'])
# solves the equations of motion  
K, M = f.setup_eom(res['x'], resonator_dict=resonator_dict)
# added: resonator_dict=resonator_dict
eigenfrequencies, evecs = f.solve_eom(K, M, sort_by_cavity_participation=True, filter_nan=True)
print(f"Eigenfrequencies: {eigenfrequencies}")
# Out:
# Eigenfrequencies: [7.99999985e+08 7.08731026e+09 6.73574416e+09 1.33983985e+10
#  1.37531417e+10]

# %% [markdown]
# ### AC electric field

# %%
X, Y = np.meshgrid(trap.dot['xlist'] * 1e-6, trap.dot['ylist'] * 1e-6)

Ex = f.Ex(X, Y)
Ey = f.Ey(X, Y)

fig = plt.figure(figsize=(5, 4.))
plt.pcolormesh(X * 1e6, Y * 1e6, Ex / 1e6, cmap=plt.cm.RdBu, vmax=0.5, vmin=-0.5)
cbar = plt.colorbar()
cbar.ax.set_ylabel(f"$E_x$ (V/{chr(956)}m)")
plt.xlabel(rf"$x$ ({chr(956)}m)")
plt.ylabel(rf"$y$ ({chr(956)}m)")
plt.gca().set_aspect('equal')

fig = plt.figure(figsize=(5, 4.))
plt.pcolormesh(X * 1e6, Y * 1e6, Ey / 1e6, cmap=plt.cm.RdBu, vmax=0.5, vmin=-0.5)
cbar = plt.colorbar()
cbar.ax.set_ylabel(f"$E_y$ (V/{chr(956)}m)")
plt.xlabel(rf"$x$ ({chr(956)}m)")
plt.ylabel(rf"$y$ ({chr(956)}m)")
plt.gca().set_aspect('equal')

# %%
fig, ax = plt.subplots(1, 3, figsize=(3 * 3., 4.))

for k in range(3):
    f.plot_potential_energy(ax=ax[k], coor=[0, 0], dxdy=(3, 3), print_voltages=False)
    ax[k].set_title(f"{eigenfrequencies[k]/1e9:.2f} GHz")
    # f.plot_electron_positions(res)

    # f.plot_eigenvector(res['x'], evecs[:, 2], color='white')
    # f.plot_eigenvector(res['x'], evecs[:, 1], color='gray')

fig.tight_layout()
anim = f.animate_eigenvectors(fig, ax, eigenvector_list=evecs.T, electron_positions=res['x'],
                              amplitude=0.25e-6)

# %%
f.show_animation(anim)
# Out:
# <video width="900" height="400" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
f.save_animation(anim, filepath="./single_electron_very_small_voltages.gif")

# %% [markdown]
# ### Voltage sweep 1

# %%
voltages = {
    'half_donut_top':0.00,
    'half_donut_bottom':0.00,
    'gate_top':-0.00,
    'gate_bottom':0.0,
    'reservoir':0.000,
    'center':0.01,
    'guard':0.000,
}

options = { "include_screening" : False, # Include screening of electron-electron interactions due to thin film.
           "screening_length" : np.inf, # Typically helium thickness.
           "potential_smoothing" : 1e-5, # Numerical smoothing of the splines (gets rid of some noise, can introduce artifacts)
           "remove_unbound_electrons" : False, # Removes electrons if they shot outside the solution box.
           "remove_bounds" : None, # Sets which electrons should be removed if above is True.
           "trap_annealing_steps" : [0.1] * 10, # List of annealing temperatures, length determines the number of steps
           "max_x_displacement" : 0.1e-6, # Maximum x-displacement of solved electron positions during annealing.
           "max_y_displacement" : 0.1e-6} # Maximum y-displacement of solved electron positions during annealing.

use_previous_initial_state = True # If True, use the previous equilibrium positions as initial condition for the next voltage sweep.

list_of_voltages = []
num_electrons=[]
electron_configurations=[]
sweep_voltages = np.linspace(0, 0.02, 101)

# if you put N electrons, you have 2N+1 eigenfrequencies
eigenfrequencies = np.zeros((len(sweep_voltages), 3))
plot = True

convergence_method='Physical gradient descent' # 'L-BFGS-B' or 'Physical gradient descent'


# Dimensionless rescaling
# -------------------------
# Base units (SI → dimensionless)
L0 = 1e-6                      # 1 μm in meters
E0 = qe                        # 1 eV in joules
M0 = me                        # electron mass in kg
Q0 = qe                        # elementary charge in C
T0 = L0 * np.sqrt(M0/E0)      # derived time unit

# Convert your physical timestep into dimensionless dt
dt_phys = 1e-13                # your original dt in seconds
dt = np.float64(dt_phys / T0)  # dimensionless

# Now redefine your usual Verlet coefficients in *this* dt
gamma    = np.float64(-0.01) / dt
prefactor= np.float64(1.0) / (1.0/dt**2 - gamma/dt)
A        = np.float64(2.0/dt**2 - gamma/dt)
B        = np.float64(1.0/dt**2)

max_timesteps = 500000# Maximum number of timesteps for the convergence method

N_init=1

with alive_progress.alive_bar(len(sweep_voltages), force_tty=True) as bar:
    for k, center in enumerate(sweep_voltages):

        voltages["half_donut_top"] = center
        voltages["half_donut_bottom"] = center
        


        f = FullModel(trap.dot, voltages, **options)


        f.set_rf_interpolator(rf_electrode_labels=['guard'])

        if k == 0: 
            electron_initial_positions = f.generate_initial_condition(N_init, center=(0, 0), radius=0.1e-6)
            N = N_init
        elif use_previous_initial_state: 
            electron_initial_positions = equilibrium_positions
            N = len(electron_initial_positions) // 2
        else:
            electron_initial_positions = None
            N = N_init
        
        
        if N > 0:
            print(f'Unloading {N} electrons with voltages: {voltages}')
            max_force=[]
            if convergence_method == 'L-BFGS-B':
                res = f.get_electron_positions(n_electrons=N, 
                                            electron_initial_positions=electron_initial_positions, 
                                            verbose=False, 
                                            suppress_warnings=False)
                equilibrium_positions = res['x']

    

            if convergence_method == 'Physical gradient descent':
                # Convert the *physical* positions into primed coords:
                r_old = (electron_initial_positions / L0).astype(np.float64)
                r_cur = r_old.copy()
                j = 2

                while True:
                    # compute physical gradient at r_phys = r_cur*L0
                    grad_phys = f.grad_total(r_cur * L0)          # in V/m
                    F = -(qe * grad_phys) * (L0/E0)     # dimensionless
                    max_force.append(np.max(np.abs(F)))
                     

                    # damped Verlet integration: dimensionless
                    r_next = prefactor * (F + r_cur * A - r_old * B)

                    # if j% 1000 == 0:
                    #     print('1: '+str(np.average(np.abs(r_cur*A-r_old*B))))
                    #     print('2: '+str(np.average(np.abs(F))))

                    # 4) Remove electrons out of domain in primed coords
                    x_next = r_next[::2];  y_next = r_next[1::2]
                    inside = np.logical_and.reduce((
                        x_next*L0 >= x_min, x_next*L0 <= x_max,
                        y_next*L0 >= y_min, y_next*L0 <= y_max
                    ))


                    r_next_filtered    = np.empty((2*np.sum(inside)), dtype=np.float64)
                    r_current_filtered = np.empty((2*np.sum(inside)), dtype=np.float64)

                    r_next_filtered[::2]    = x_next[inside]
                    r_next_filtered[1::2]   = y_next[inside]
                    r_current_filtered[::2] = r_cur[::2][inside]
                    r_current_filtered[1::2]= r_cur[1::2][inside]

                    # rotate for next pass
                    r_old, r_cur = r_current_filtered, r_next_filtered

                    j += 1

                    # 5) Check convergence in dimensionless force
                    if len(r_cur)==0:
                        print(f'During the convergence, no electrons left after {j} steps.')
                        break
                       
                    if np.max(np.abs(F)) < 1e-13:
                        print(f'Converged after {j} steps.')
                        r_cur = r_next_filtered
                        break


                    if j >= max_timesteps:
                        print(f'Not converged after {max_timesteps} steps.')
                        break

                # Convert *back* to physical coordinates (meters)
                equilibrium_positions = (r_cur * L0)
                print(np.linalg.norm(r_cur-r_old))
                print(max_force[-1])


            num_electrons.append(f.count_electrons_in_dot(equilibrium_positions, trap_bounds_x=(-1.5*1e-6,1.5*1e-6), trap_bounds_y=(-1.5*1e-6,1.5*1e-6))) #if trap_bounds_x,y is not specified, the default value is (-1e-6, 1e-6) for both x and y.
            print('There are '+str(num_electrons[k])+' electrons in the dot.')
            final_x, final_y = r2xy(equilibrium_positions)
            electron_configurations.append(equilibrium_positions)
            list_of_voltages.append(voltages.copy())
    

        K, M = f.setup_eom(equilibrium_positions, resonator_dict=resonator_dict)
        eigenfrequencies[k, :], evecs = f.solve_eom(K, M, sort_by_cavity_participation=True)

        bar()




plt.figure()
plt.plot(sweep_voltages, eigenfrequencies / 1e9)
plt.xlabel(" Voltages (V)")
plt.ylabel("Frequency (GHz)")
plt.xlim(np.min(sweep_voltages), np.max(sweep_voltages))
# Out:
# on 0: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0), 'half_donut_bottom': np.float64(0.0), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 0: Converged after 3950 steps.
# on 0: 2.543969809377951e-12
# on 0: 7.265380103094188e-14
# on 0: There are 1 electrons in the dot.
# on 1: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0002), 'half_donut_bottom': np.float64(0.0002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 1: Converged after 4056 steps.
# on 1: 5.0146330203994865e-14
# on 1: 9.984818527541962e-14
# on 1: There are 1 electrons in the dot.
# on 2: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0004), 'half_donut_bottom': np.float64(0.0004), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 2: Converged after 3794 steps.
# on 2: 3.394236974141684e-13
# on 2: 9.947450335667795e-14
# on 2: There are 1 electrons in the dot.
# on 3: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0006000000000000001), 'half_donut_bottom': np.float64(0.0006000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 3: Converged after 3931 steps.
# on 3: 3.9257917775114976e-14
# on 3: 9.958100777307521e-14
# on 3: There are 1 electrons in the dot.
# on 4: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0008), 'half_donut_bottom': np.float64(0.0008), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 4: Converged after 3894 steps.
# on 4: 5.0724166915873896e-14
# on 4: 9.91914514969494e-14
# on 4: There are 1 electrons in the dot.
# on 5: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.001), 'half_donut_bottom': np.float64(0.001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 5: Converged after 3819 steps.
# on 5: 6.245939392279845e-14
# on 5: 9.990518928804092e-14
# on 5: There are 1 electrons in the dot.
# on 6: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0012000000000000001), 'half_donut_bottom': np.float64(0.0012000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 6: Converged after 4131 steps.
# on 6: 2.726470583783819e-14
# on 6: 9.948549895000267e-14
# on 6: There are 1 electrons in the dot.
# on 7: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0014), 'half_donut_bottom': np.float64(0.0014), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 7: Converged after 4532 steps.
# on 7: 3.185318922018991e-14
# on 7: 9.962129438045864e-14
# on 7: There are 1 electrons in the dot.
# on 8: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0016), 'half_donut_bottom': np.float64(0.0016), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 8: Converged after 3882 steps.
# on 8: 3.606366238958741e-14
# on 8: 9.932825761893582e-14
# on 8: There are 1 electrons in the dot.
# on 9: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0018000000000000002), 'half_donut_bottom': np.float64(0.0018000000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 9: Converged after 4672 steps.
# on 9: 3.038647681566793e-14
# on 9: 9.967951047906708e-14
# on 9: There are 1 electrons in the dot.
# on 10: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.002), 'half_donut_bottom': np.float64(0.002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 10: Converged after 6563 steps.
# on 10: 2.542064301915858e-14
# on 10: 9.98171436616957e-14
# on 10: There are 1 electrons in the dot.
# on 11: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0022), 'half_donut_bottom': np.float64(0.0022), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 11: Converged after 5239 steps.
# on 11: 2.830552407624312e-14
# on 11: 9.98505012839157e-14
# on 11: There are 1 electrons in the dot.
# on 12: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0024000000000000002), 'half_donut_bottom': np.float64(0.0024000000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 12: Converged after 3828 steps.
# on 12: 1.2316848750784398e-13
# on 12: 9.960635624639557e-14
# on 12: There are 1 electrons in the dot.
# on 13: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0026000000000000003), 'half_donut_bottom': np.float64(0.0026000000000000003), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 13: Converged after 4010 steps.
# on 13: 6.413931197231461e-14
# on 13: 9.965318886751005e-14
# on 13: There are 1 electrons in the dot.
# on 14: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0028), 'half_donut_bottom': np.float64(0.0028), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 14: Converged after 4455 steps.
# on 14: 3.623696758724033e-14
# on 14: 9.999302619592698e-14
# on 14: There are 1 electrons in the dot.
# on 15: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.003), 'half_donut_bottom': np.float64(0.003), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 15: Converged after 4930 steps.
# on 15: 2.916088124312203e-14
# on 15: 9.9808953515218e-14
# on 15: There are 1 electrons in the dot.
# on 16: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0032), 'half_donut_bottom': np.float64(0.0032), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 16: Converged after 4630 steps.
# on 16: 3.101310056962321e-14
# on 16: 9.957096876785781e-14
# on 16: There are 1 electrons in the dot.
# on 17: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0034000000000000002), 'half_donut_bottom': np.float64(0.0034000000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 17: Converged after 6011 steps.
# on 17: 2.7866597931589963e-14
# on 17: 9.983686672428853e-14
# on 17: There are 1 electrons in the dot.
# on 18: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0036000000000000003), 'half_donut_bottom': np.float64(0.0036000000000000003), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 18: Converged after 6128 steps.
# on 18: 2.6706079758246898e-14
# on 18: 9.995421092808681e-14
# on 18: There are 1 electrons in the dot.
# on 19: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0038), 'half_donut_bottom': np.float64(0.0038), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 19: Converged after 5541 steps.
# on 19: 2.7280370833170536e-14
# on 19: 9.982592708013272e-14
# on 19: There are 1 electrons in the dot.
# on 20: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.004), 'half_donut_bottom': np.float64(0.004), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 20: Converged after 6425 steps.
# on 20: 2.5755441175097046e-14
# on 20: 9.970278824766865e-14
# on 20: There are 1 electrons in the dot.
# on 21: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.004200000000000001), 'half_donut_bottom': np.float64(0.004200000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 21: Converged after 4066 steps.
# on 21: 4.930953370856497e-14
# on 21: 9.985762258746256e-14
# on 21: There are 1 electrons in the dot.
# on 22: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0044), 'half_donut_bottom': np.float64(0.0044), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 22: Converged after 3528 steps.
# on 22: 2.1888130369795075e-14
# on 22: 9.984261062356835e-14
# on 22: There are 1 electrons in the dot.
# on 23: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0046), 'half_donut_bottom': np.float64(0.0046), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 23: Converged after 4108 steps.
# on 23: 4.343829127348291e-14
# on 23: 9.965224645469561e-14
# on 23: There are 1 electrons in the dot.
# on 24: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0048000000000000004), 'half_donut_bottom': np.float64(0.0048000000000000004), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 24: Converged after 5098 steps.
# on 24: 2.805352698676016e-14
# on 24: 9.978386036890717e-14
# on 24: There are 1 electrons in the dot.
# on 25: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.005), 'half_donut_bottom': np.float64(0.005), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 25: Converged after 3754 steps.
# on 25: 8.485800734638994e-14
# on 25: 9.994103389310281e-14
# on 25: There are 1 electrons in the dot.
# on 26: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.005200000000000001), 'half_donut_bottom': np.float64(0.005200000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 26: Converged after 4442 steps.
# on 26: 3.143968407800315e-14
# on 26: 9.987291328238805e-14
# on 26: There are 1 electrons in the dot.
# on 27: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0054), 'half_donut_bottom': np.float64(0.0054), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 27: Converged after 3736 steps.
# on 27: 1.0699493939695274e-13
# on 27: 9.975040189680318e-14
# on 27: There are 1 electrons in the dot.
# on 28: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0056), 'half_donut_bottom': np.float64(0.0056), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 28: Converged after 6661 steps.
# on 28: 2.4634834380018562e-14
# on 28: 9.988428167906349e-14
# on 28: There are 1 electrons in the dot.
# on 29: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0058000000000000005), 'half_donut_bottom': np.float64(0.0058000000000000005), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 29: Converged after 5054 steps.
# on 29: 2.6137123745018525e-14
# on 29: 9.990155686034896e-14
# on 29: There are 1 electrons in the dot.
# on 30: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.006), 'half_donut_bottom': np.float64(0.006), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 30: Converged after 4803 steps.
# on 30: 3.425609321186534e-14
# on 30: 9.96523372986946e-14
# on 30: There are 1 electrons in the dot.
# on 31: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.006200000000000001), 'half_donut_bottom': np.float64(0.006200000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 31: Converged after 4217 steps.
# on 31: 3.403742774460669e-14
# on 31: 9.997455879817708e-14
# on 31: There are 1 electrons in the dot.
# on 32: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0064), 'half_donut_bottom': np.float64(0.0064), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 32: Converged after 4198 steps.
# on 32: 3.52750685415271e-14
# on 32: 9.96054602964147e-14
# on 32: There are 1 electrons in the dot.
# on 33: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0066), 'half_donut_bottom': np.float64(0.0066), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 33: Converged after 4353 steps.
# on 33: 4.541378839748693e-14
# on 33: 9.936471395688429e-14
# on 33: There are 1 electrons in the dot.
# on 34: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0068000000000000005), 'half_donut_bottom': np.float64(0.0068000000000000005), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 34: Converged after 3981 steps.
# on 34: 3.845121006534565e-14
# on 34: 9.985135867489683e-14
# on 34: There are 1 electrons in the dot.
# on 35: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.007), 'half_donut_bottom': np.float64(0.007), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 35: Converged after 4973 steps.
# on 35: 3.1317277043144466e-14
# on 35: 9.97924738399547e-14
# on 35: There are 1 electrons in the dot.
# on 36: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.007200000000000001), 'half_donut_bottom': np.float64(0.007200000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 36: Converged after 4093 steps.
# on 36: 4.074708181717564e-14
# on 36: 9.979230353174272e-14
# on 36: There are 1 electrons in the dot.
# on 37: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0074), 'half_donut_bottom': np.float64(0.0074), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 37: Converged after 4524 steps.
# on 37: 3.535443991841205e-14
# on 37: 9.972816068272439e-14
# on 37: There are 1 electrons in the dot.
# on 38: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0076), 'half_donut_bottom': np.float64(0.0076), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 38: Converged after 5965 steps.
# on 38: 3.422806827325764e-14
# on 38: 9.99334852647138e-14
# on 38: There are 1 electrons in the dot.
# on 39: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0078000000000000005), 'half_donut_bottom': np.float64(0.0078000000000000005), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 39: Converged after 5633 steps.
# on 39: 3.1003642272030366e-14
# on 39: 9.971719760332176e-14
# on 39: There are 1 electrons in the dot.
# on 40: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.008), 'half_donut_bottom': np.float64(0.008), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 40: Converged after 8376 steps.
# on 40: 2.352793657950547e-14
# on 40: 9.982331464208904e-14
# on 40: There are 1 electrons in the dot.
# on 41: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0082), 'half_donut_bottom': np.float64(0.0082), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 41: Converged after 6896 steps.
# on 41: 2.670450696804471e-14
# on 41: 9.974053558721093e-14
# on 41: There are 1 electrons in the dot.
# on 42: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.008400000000000001), 'half_donut_bottom': np.float64(0.008400000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 42: Converged after 7422 steps.
# on 42: 2.4862202481692743e-14
# on 42: 9.982519369455822e-14
# on 42: There are 1 electrons in the dot.
# on 43: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0086), 'half_donut_bottom': np.float64(0.0086), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 43: Converged after 8187 steps.
# on 43: 2.2100718324157103e-14
# on 43: 9.994814051395018e-14
# on 43: There are 1 electrons in the dot.
# on 44: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0088), 'half_donut_bottom': np.float64(0.0088), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 44: Converged after 9812 steps.
# on 44: 3.139601310827396e-14
# on 44: 9.984863962204937e-14
# on 44: There are 1 electrons in the dot.
# on 45: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.009000000000000001), 'half_donut_bottom': np.float64(0.009000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 45: Converged after 8154 steps.
# on 45: 3.1725483366114574e-14
# on 45: 9.995324526390626e-14
# on 45: There are 1 electrons in the dot.
# on 46: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0092), 'half_donut_bottom': np.float64(0.0092), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 46: Converged after 11268 steps.
# on 46: 2.1377887560196872e-14
# on 46: 9.999818056938282e-14
# on 46: There are 1 electrons in the dot.
# on 47: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0094), 'half_donut_bottom': np.float64(0.0094), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 47: Converged after 12000 steps.
# on 47: 2.931098045090602e-14
# on 47: 9.997099237324392e-14
# on 47: There are 1 electrons in the dot.
# on 48: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.009600000000000001), 'half_donut_bottom': np.float64(0.009600000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 48: Converged after 11682 steps.
# on 48: 2.1546658650276383e-14
# on 48: 9.995133049001124e-14
# on 48: There are 1 electrons in the dot.
# on 49: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0098), 'half_donut_bottom': np.float64(0.0098), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 49: Converged after 21039 steps.
# on 49: 2.0678736906169003e-14
# on 49: 9.991122150269927e-14
# on 49: There are 1 electrons in the dot.
# on 50: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.01), 'half_donut_bottom': np.float64(0.01), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 50: Converged after 14400 steps.
# on 50: 2.1543859559089732e-14
# on 50: 9.992315772033855e-14
# on 50: There are 1 electrons in the dot.
# on 51: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0102), 'half_donut_bottom': np.float64(0.0102), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 51: Converged after 12614 steps.
# on 51: 2.2124344189301956e-14
# on 51: 9.994450341638261e-14
# on 51: There are 1 electrons in the dot.
# on 52: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.010400000000000001), 'half_donut_bottom': np.float64(0.010400000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 52: Converged after 13798 steps.
# on 52: 2.428717481879652e-14
# on 52: 9.989639992991072e-14
# on 52: There are 1 electrons in the dot.
# on 53: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0106), 'half_donut_bottom': np.float64(0.0106), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 53: Converged after 13768 steps.
# on 53: 2.1206025225964575e-14
# on 53: 9.9915028028974e-14
# on 53: There are 1 electrons in the dot.
# on 54: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0108), 'half_donut_bottom': np.float64(0.0108), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 54: Converged after 14362 steps.
# on 54: 2.1148429617624433e-14
# on 54: 9.993799177099304e-14
# on 54: There are 1 electrons in the dot.
# on 55: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.011000000000000001), 'half_donut_bottom': np.float64(0.011000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 55: Converged after 14116 steps.
# on 55: 2.0637096474295002e-14
# on 55: 9.987745680506421e-14
# on 55: There are 1 electrons in the dot.
# on 56: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0112), 'half_donut_bottom': np.float64(0.0112), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 56: Converged after 13095 steps.
# on 56: 2.4764850188928098e-14
# on 56: 9.98936736107403e-14
# on 56: There are 1 electrons in the dot.
# on 57: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0114), 'half_donut_bottom': np.float64(0.0114), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 57: Converged after 13478 steps.
# on 57: 2.5256893791848405e-14
# on 57: 9.995710771593114e-14
# on 57: There are 1 electrons in the dot.
# on 58: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.011600000000000001), 'half_donut_bottom': np.float64(0.011600000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 58: Converged after 14399 steps.
# on 58: 2.3493863631778594e-14
# on 58: 9.997029688790792e-14
# on 58: There are 1 electrons in the dot.
# on 59: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0118), 'half_donut_bottom': np.float64(0.0118), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 59: Converged after 17335 steps.
# on 59: 2.5550611581463074e-14
# on 59: 9.991663251461558e-14
# on 59: There are 1 electrons in the dot.
# on 60: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.012), 'half_donut_bottom': np.float64(0.012), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 60: Converged after 17602 steps.
# on 60: 2.0351537778539705e-14
# on 60: 9.997766153846399e-14
# on 60: There are 1 electrons in the dot.
# on 61: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0122), 'half_donut_bottom': np.float64(0.0122), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 61: Converged after 20576 steps.
# on 61: 2.618392746680107e-14
# on 61: 9.99200249747565e-14
# on 61: There are 1 electrons in the dot.
# on 62: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.012400000000000001), 'half_donut_bottom': np.float64(0.012400000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 62: Converged after 22739 steps.
# on 62: 2.0124357399769563e-14
# on 62: 9.994389644585408e-14
# on 62: There are 1 electrons in the dot.
# on 63: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0126), 'half_donut_bottom': np.float64(0.0126), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 63: Converged after 26301 steps.
# on 63: 1.8829555969990253e-14
# on 63: 9.997883913836525e-14
# on 63: There are 1 electrons in the dot.
# on 64: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0128), 'half_donut_bottom': np.float64(0.0128), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 64: Converged after 29460 steps.
# on 64: 1.8671714990232707e-14
# on 64: 9.998840974027173e-14
# on 64: There are 1 electrons in the dot.
# on 65: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.013000000000000001), 'half_donut_bottom': np.float64(0.013000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 65: Converged after 35649 steps.
# on 65: 1.8486948083484833e-14
# on 65: 9.997889685803631e-14
# on 65: There are 1 electrons in the dot.
# on 66: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0132), 'half_donut_bottom': np.float64(0.0132), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 66: Converged after 29479 steps.
# on 66: 1.878414915801967e-14
# on 66: 9.997380050717763e-14
# on 66: There are 1 electrons in the dot.
# on 67: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0134), 'half_donut_bottom': np.float64(0.0134), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 67: Converged after 52857 steps.
# on 67: 1.8236280541206185e-14
# on 67: 9.998610094535892e-14
# on 67: There are 1 electrons in the dot.
# on 68: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.013600000000000001), 'half_donut_bottom': np.float64(0.013600000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 68: Converged after 72768 steps.                                              ▃▁▃ 68/101 [67%] in 1:00 (~29s, 1.1/s
# on 68: 1.809750266312804e-14
# on 68: 9.999502650124557e-14
# on 68: There are 1 electrons in the dot.
# on 69: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.013800000000000002), 'half_donut_bottom': np.float64(0.013800000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 69: Converged after 116004 steps.                                             ▆▄▂ 69/101 [68%] in 1:02 (~28s, 1.1/s
# on 69: 1.7970000487643745e-14
# on 69: 9.999217089938986e-14
# on 69: There are 1 electrons in the dot.
# on 70: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.014), 'half_donut_bottom': np.float64(0.014), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 70: Converged after 273657 steps.
# on 70: 1.7857243461705252e-14
# on 70: 9.999619469264198e-14
# on 70: There are 1 electrons in the dot.
# on 71: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0142), 'half_donut_bottom': np.float64(0.0142), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 71: Converged after 165661 steps.
# on 71: 2.4168477255160382e-14
# on 71: 9.998347438866517e-14
# on 71: There are 1 electrons in the dot.
# on 72: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.014400000000000001), 'half_donut_bottom': np.float64(0.014400000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 72: Converged after 68897 steps.
# on 72: 2.4355228974648043e-14
# on 72: 9.999860339782173e-14
# on 72: There are 1 electrons in the dot.
# on 73: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0146), 'half_donut_bottom': np.float64(0.0146), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 73: Converged after 66268 steps.
# on 73: 2.4176763353717082e-14
# on 73: 9.998066691219163e-14
# on 73: There are 1 electrons in the dot.
# on 74: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0148), 'half_donut_bottom': np.float64(0.0148), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 74: Converged after 65672 steps.
# on 74: 2.4314898120457263e-14
# on 74: 9.998040347014568e-14
# on 74: There are 1 electrons in the dot.
# on 75: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.015000000000000001), 'half_donut_bottom': np.float64(0.015000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 75: Converged after 61267 steps.
# on 75: 2.4778874656579398e-14
# on 75: 9.99627617834231e-14
# on 75: There are 1 electrons in the dot.
# on 76: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0152), 'half_donut_bottom': np.float64(0.0152), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 76: Converged after 72127 steps.
# on 76: 1.5737411374061594e-14
# on 76: 9.998850418468929e-14
# on 76: There are 1 electrons in the dot.
# on 77: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0154), 'half_donut_bottom': np.float64(0.0154), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 77: Converged after 63997 steps.
# on 77: 2.4923085084465454e-14
# on 77: 9.997081748362723e-14
# on 77: There are 1 electrons in the dot.
# on 78: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.015600000000000001), 'half_donut_bottom': np.float64(0.015600000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 78: Converged after 63113 steps.
# on 78: 2.4919313781983086e-14
# on 78: 9.998232893075046e-14
# on 78: There are 1 electrons in the dot.
# on 79: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0158), 'half_donut_bottom': np.float64(0.0158), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 79: Converged after 63153 steps.
# on 79: 2.5024387570476097e-14
# on 79: 9.998576899761247e-14
# on 79: There are 1 electrons in the dot.
# on 80: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.016), 'half_donut_bottom': np.float64(0.016), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 80: Converged after 62338 steps.
# on 80: 2.5126385398813156e-14
# on 80: 9.998304761893449e-14
# on 80: There are 1 electrons in the dot.
# on 81: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0162), 'half_donut_bottom': np.float64(0.0162), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 81: Converged after 60862 steps.
# on 81: 2.4702462297909733e-14
# on 81: 9.9972069733667e-14
# on 81: There are 1 electrons in the dot.
# on 82: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0164), 'half_donut_bottom': np.float64(0.0164), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 82: Converged after 59963 steps.
# on 82: 2.4842217028995475e-14
# on 82: 9.997372529824132e-14
# on 82: There are 1 electrons in the dot.
# on 83: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0166), 'half_donut_bottom': np.float64(0.0166), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 83: Converged after 48963 steps.
# on 83: 2.7217678441791293e-14
# on 83: 9.997079075674264e-14
# on 83: There are 1 electrons in the dot.
# on 84: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.016800000000000002), 'half_donut_bottom': np.float64(0.016800000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 84: Converged after 45992 steps.
# on 84: 2.672226331350675e-14
# on 84: 9.998073835504328e-14
# on 84: There are 1 electrons in the dot.
# on 85: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.017), 'half_donut_bottom': np.float64(0.017), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 85: Converged after 59899 steps.
# on 85: 2.7422508708241367e-14
# on 85: 9.996415428759065e-14
# on 85: There are 1 electrons in the dot.
# on 86: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0172), 'half_donut_bottom': np.float64(0.0172), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 86: Converged after 47842 steps.
# on 86: 2.727739120580975e-14
# on 86: 9.997913963388781e-14
# on 86: There are 1 electrons in the dot.
# on 87: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.017400000000000002), 'half_donut_bottom': np.float64(0.017400000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 87: Converged after 46587 steps.
# on 87: 2.747375806685963e-14
# on 87: 9.996359295882939e-14
# on 87: There are 1 electrons in the dot.
# on 88: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0176), 'half_donut_bottom': np.float64(0.0176), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 88: Converged after 57291 steps.
# on 88: 1.526990593458353e-14
# on 88: 9.998164163249611e-14
# on 88: There are 1 electrons in the dot.
# on 89: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0178), 'half_donut_bottom': np.float64(0.0178), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 89: Converged after 44584 steps.
# on 89: 1.49319837694036e-14
# on 89: 9.999918570979814e-14
# on 89: There are 1 electrons in the dot.
# on 90: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.018000000000000002), 'half_donut_bottom': np.float64(0.018000000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 90: Converged after 43749 steps.
# on 90: 1.5384202254451112e-14
# on 90: 9.997331607003444e-14
# on 90: There are 1 electrons in the dot.
# on 91: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0182), 'half_donut_bottom': np.float64(0.0182), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 91: Converged after 42810 steps.
# on 91: 1.5168263360990462e-14
# on 91: 9.998653327514262e-14
# on 91: There are 1 electrons in the dot.
# on 92: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0184), 'half_donut_bottom': np.float64(0.0184), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 92: Converged after 41820 steps.
# on 92: 1.5361350844315293e-14
# on 92: 9.999937916616019e-14
# on 92: There are 1 electrons in the dot.
# on 93: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.018600000000000002), 'half_donut_bottom': np.float64(0.018600000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 93: Converged after 40665 steps.
# on 93: 1.4876988529977098e-14
# on 93: 9.998487437989922e-14
# on 93: There are 1 electrons in the dot.
# on 94: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0188), 'half_donut_bottom': np.float64(0.0188), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 94: Converged after 52013 steps.
# on 94: 2.1797794967928332e-14
# on 94: 9.9987488511033e-14
# on 94: There are 1 electrons in the dot.
# on 95: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.019), 'half_donut_bottom': np.float64(0.019), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 95: Converged after 45033 steps.
# on 95: 1.4950236207163517e-14
# on 95: 9.997123839866618e-14
# on 95: There are 1 electrons in the dot.
# on 96: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.019200000000000002), 'half_donut_bottom': np.float64(0.019200000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 96: Converged after 44727 steps.
# on 96: 1.4894067047868032e-14
# on 96: 9.99900535703091e-14
# on 96: There are 1 electrons in the dot.
# on 97: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0194), 'half_donut_bottom': np.float64(0.0194), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 97: Converged after 44398 steps.
# on 97: 1.4981018908451382e-14
# on 97: 9.998368000196934e-14
# on 97: There are 1 electrons in the dot.
# on 98: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0196), 'half_donut_bottom': np.float64(0.0196), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 98: Converged after 44059 steps.
# on 98: 1.479057097542559e-14
# on 98: 9.9972069733667e-14
# on 98: There are 1 electrons in the dot.
# on 99: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0198), 'half_donut_bottom': np.float64(0.0198), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 99: Converged after 43715 steps.
# on 99: 1.4767322640714007e-14
# on 99: 9.997639693892778e-14
# on 99: There are 1 electrons in the dot.
# on 100: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.02), 'half_donut_bottom': np.float64(0.02), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 100: Converged after 43342 steps.
# on 100: 1.4767322640714007e-14
# on 100: 9.998880301509416e-14
# on 100: There are 1 electrons in the dot.
# |████████████████████████████████████████| 101/101 [100%] in 3:35.2 (0.47/s)
# (0.0, 0.02)

# %%
fig, ax = plt.subplots(figsize=(7, 4.))

anim = f.animate_voltage_sweep(fig, ax,  list_of_voltages=list_of_voltages, list_of_electron_positions=electron_configurations,
                            dxdy=(3.8, 4), frame_interval_ms=100 )
f.show_animation(anim)
# Out:
# <video width="700" height="400" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
plt.plot(sweep_voltages, eigenfrequencies[:, 0])
plt.ylabel("Resonator frequency (Hz)")
plt.xlim(np.min(sweep_voltages), np.max(sweep_voltages))
# Out:
# (0.0, 0.02)

# %% [markdown]
# ### Voltage sweep 2

# %%
sweep_voltages = np.linspace(0.0012, 0.002, 101)
eigenfrequencies = np.zeros((len(sweep_voltages), 3))
plot = True

convergence_method='L-BFGS-B' # 'L-BFGS-B' or 'Physical gradient descent'

sweep_electrode = "half_donut_top"
vi = voltages[sweep_electrode]

with alive_progress.alive_bar(len(sweep_voltages), force_tty=True) as bar:
    for k, center in enumerate(sweep_voltages):

        voltages[sweep_electrode] = center

        N = 50

        f = FullModel(trap.dot, voltages, **options)
        f.remove_unbound_electrons = False
        f.trap_annealing_steps = [0.5] * 25

        f.set_rf_interpolator(rf_electrode_labels=['guard'])


        if k == 0:
            initial_condition = f.generate_initial_condition(N)
        else:
            initial_condition = equilibrium_positions

        if convergence_method == 'L-BFGS-B':

            init_x, init_y = r2xy(initial_condition)
            res = f.get_electron_positions(n_electrons=N, electron_initial_positions=initial_condition, verbose=False, gradient_tolerance=1e-9, ftol=1e-300)
            equilibrium_positions= res['x']
            electron_configurations.append(equilibrium_positions)
            final_x, final_y = r2xy(equilibrium_positions)
            if res['status'] != 0:
                print(f"Error at k={k}, status={res['status']}")
                print(f"Error message: {res['message']}")
                continue

        
        elif convergence_method == 'Physical gradient descent':
            n_timesteps = 6000
            dt = 1e-13 
            gamma = -0.01 * me / dt # This is the damping parameter. 
            r = np.zeros((2 * N, n_timesteps+2))

            r[:, 0] = initial_condition
            r[:, 1] = initial_condition

            for j in range(2, n_timesteps+2):
                prefactor = 1 / (me / dt ** 2 - gamma / dt)
                F = - qe * f.grad_total(r[:, j-1])
                r[:, j] = prefactor * (F - r[:, j-1] * (-2 * me / dt ** 2 + gamma / dt) - r[:, j-2] * me / dt ** 2)
                
            equilibrium_positions = r[:, -1]
            electron_configurations.append(equilibrium_positions)
            final_x, final_y = r2xy(equilibrium_positions)

    


       

        # if plot and not(k%10):
        #     f.plot_potential_energy(coor=[0, 0], dxdy=(3, 3))
        #     f.plot_electron_positions(res)

        # added: resonaotor_dict
    

        K, M = f.setup_eom(equilibrium_positions, resonator_dict=resonator_dict)
        eigenfrequencies[k, :], evecs = f.solve_eom(K, M, sort_by_cavity_participation=True)

        bar()




plt.figure()
plt.plot(sweep_voltages, eigenfrequencies / 1e9)
plt.xlabel(" Voltages (V)")
plt.ylabel("Frequency (GHz)")
plt.xlim(np.min(sweep_voltages), np.max(sweep_voltages))
# Out:
# |████████████████████████████████████████| 101/101 [100%] in 12.1s (8.35/s)
# (0.0012, 0.002)

# %%
N = 2

f = FullModel(trap.dot, voltages, **options)
f.remove_unbound_electrons = False
f.trap_annealing_steps = [4] * 25

f.set_rf_interpolator(rf_electrode_labels=['guard'])

initial_condition = f.generate_initial_condition(N)
init_x, init_y = r2xy(initial_condition)

res = f.get_electron_positions(n_electrons=N, electron_initial_positions=None, verbose=False)

final_x, final_y = r2xy(res['x'])

f.plot_potential_energy(coor=[0, 0], dxdy=(4, 4))
f.plot_electron_positions(res)


K, M = f.setup_eom(res['x'], resonator_dict=resonator_dict)
eigenfrequencies, evecs = f.solve_eom(K, M, sort_by_cavity_participation=True)
f.plot_eigenvector(res['x'], evecs[:, 2], color='white')
f.plot_eigenvector(res['x'], evecs[:, 1], color='gray')

print(eigenfrequencies)
# Out:
# [7.99999977e+08 4.67440870e+09 1.08496049e+10 6.69986487e+09
#  9.95985279e+09]

# %%
f.plot_convergence()

# %%
# difference between the mode most coupled to the resonator and the resonator frequency
f.get_cavity_frequency_shift(K, M)
# Out:
# np.float64(-23.18082332611084)

# %% [markdown]
# ## Unloading

# %% [markdown]
# ### Options and widgets

# %%
from quantum_electron.utils import crop_potential



left_boundary = -5 # microns

voltages = {
    'half_donut_top':0.05,
    'half_donut_bottom':0.05,
    'gate_top':-0.03,
    'gate_bottom':-0.03,
    'reservoir':0.05,
    'center':0.0,
    'guard':0.0,
}

for electrode in voltages.keys():
    new_x, new_y, new_U = crop_potential(x=trap.dot['xlist'], y=trap.dot['ylist'], U=trap.dot[electrode], 
                                         xrange=(left_boundary, 2), yrange=(-4, 4))
    
    trap.dot[electrode] = new_U

trap.dot['xlist'] = new_x 
trap.dot['ylist'] = new_y
 
x_min= np.min(trap.dot['xlist'])*1e-6
x_max= np.max(trap.dot['xlist'])*1e-6
y_min= np.min(trap.dot['ylist'])*1e-6
y_max= np.max(trap.dot['ylist'])*1e-6
print(f"Potential grid: x_min={x_min:.2e}, x_max={x_max:.2e}, y_min={y_min:.2e}, y_max={y_max:.2e}")




options = { "include_screening" : False, # Include screening of electron-electron interactions due to thin film.
           "screening_length" : np.inf, # Typically helium thickness.
           "potential_smoothing" : 1e-5, # Numerical smoothing of the splines (gets rid of some noise, can introduce artifacts)
           "remove_unbound_electrons" : False, # Removes electrons if they shot outside the solution box.
           "remove_bounds" : None, # Sets which electrons should be removed if above is True.
           "trap_annealing_steps" : [0.1] * 10, # List of annealing temperatures, length determines the number of steps
           "max_x_displacement" : 0.1e-6, # Maximum x-displacement of solved electron positions during annealing.
           "max_y_displacement" : 0.1e-6} # Maximum y-displacement of solved electron positions during annealing.



fig, ax = plt.subplots()
fm = FullModel(trap.dot, voltages, **options)
fm.plot_potential_energy(ax=ax, coor=[0,0], dxdy=(10, 8))
ax.set_xlim(-5, 2)
# Out:
# Potential grid: x_min=-5.00e-06, x_max=1.98e-06, y_min=-4.00e-06, y_max=3.98e-06
# (-5.0, 2.0)

# %%
Vrms = 140e-9
f0 = 0.800e9

Z = 2 / 1.055e-34 * (Vrms / (2 * np.pi * f0)) ** 2

resonator_dict = {"f0" : f0, # Resonance frequency for the resonator (only used for solving motional frequencies)
           "Z0" : Z }# Resonator impedance (only used for solving motional frequencies)

# %% [markdown]
# ### Unloading the dot

# %%
# cavity_freqs_list = []
# electron_modef_list=[]
# voltages_list = []


# for f0 in [0.120945e9, 0.400e9, 0.600e9, 0.800e9]:
    
#     resonator_dict = {"f0" : f0, # Resonance frequency for the resonator (only used for solving motional frequencies)
#            "Z0" : Z }# Resonator impedance (only used for solving motional frequencies)


voltages = {
    'half_donut_top':0.2,
    'half_donut_bottom':-0.5,
    'gate_top':0.0,
    'gate_bottom':-0.5,
    'reservoir':-0.5,
    'center':0.0,
    'guard':0.0,
}

random.seed()

use_previous_initial_state = True
unload_voltages = np.linspace(0.7, 1.5, 200) # for the gates
unload_voltages_dot=np.linspace(0.05, -0.01, 200) # for the top half-donut and the center
list_of_voltages=[]
# unload_voltages_forward = np.linspace(0.007, 0.0005, 100) # for the reservoir
# unload_voltages_backward = unload_voltages_forward[::-1][1:]
# unload_voltages=np.concatenate((unload_voltages_forward, unload_voltages_backward))

# Initial number of electrons to start with
N_init = 5

temperature = 1.2 # Only important for calculation of the Gamma = Ec / Ek

# Keep track of some variables
energies = np.zeros(len(unload_voltages))
num_electrons = np.zeros(len(unload_voltages))
cavity_freqs=[]
electron_configurations = []
list_of_eigenvectors=[]
num_electrons_chgd_disk = np.zeros(len(unload_voltages))
num_electrons_par_cap = np.zeros(len(unload_voltages))
densities = np.zeros(len(unload_voltages))
gamma_param = np.zeros(len(unload_voltages))
disc_capacitances = np.zeros(len(unload_voltages))
electron_modef = []
trap_depth = np.zeros(len(unload_voltages))  
# Choose the convergence method for the calculation of the electron positions at equilibrium.
convergence_method = 'Physical gradient descent' # 'L-BFGS-B' or 'Physical gradient descent'



# Dimensionless rescaling
# Base units (SI → dimensionless)
L0 = 1e-6                      # 1 μm in meters
E0 = qe                        # 1 eV in joules
M0 = me                        # electron mass in kg
Q0 = qe                        # elementary charge in C
T0 = L0 * np.sqrt(M0/E0)      # derived time unit

# Convert physical timestep into dimensionless dt
dt_phys = 1e-13                # your original dt in seconds
dt = np.float64(dt_phys / T0)  # dimensionless

# redefine usual Verlet coefficients
gamma    = np.float64(-0.01) / dt
prefactor= np.float64(1.0) / (1.0/dt**2 - gamma/dt)
A        = np.float64(2.0/dt**2 - gamma/dt)
B        = np.float64(1.0/dt**2)

max_timesteps = 4000000 # Maximum number of timesteps for the convergence method

with alive_progress.alive_bar(len(unload_voltages), force_tty=True) as bar:
    for k, unload in enumerate(unload_voltages):

        # Here you can change how to unload the electrons (which electrodes to sweep)
        # voltages['center'] = unload
        # voltages['half_donut_top'] = unload
        # voltages['half_donut_bottom'] = unload
    
        voltages['gate_top'] = unload
        # voltages['half_donut_top'] = unload_voltages_dot[k]
        # voltages['half_donut_top']=unload_voltages_dot[k]
        # voltages['reservoir']=unload
        
        
        
        f = FullModel(trap.dot, voltages, **options)

        f.set_rf_interpolator(rf_electrode_labels=['gate_top'])
        
        if k == 0: 
            electron_initial_positions = f.generate_initial_condition(N_init, center=(0, 0), radius=0.1e-6)
            N = N_init
        elif use_previous_initial_state: 
            electron_initial_positions = equilibrium_positions
            N = len(electron_initial_positions) // 2
        else:
            electron_initial_positions = None
            N = N_init
        
        
        if N > 0:
            print(f'Unloading {N} electrons with voltages: {voltages}')
            max_force=[]
            if convergence_method == 'L-BFGS-B':
                res = f.get_electron_positions(n_electrons=N, 
                                            electron_initial_positions=electron_initial_positions, 
                                            verbose=False, 
                                            suppress_warnings=False)
                equilibrium_positions = res['x']

    

            if convergence_method == 'Physical gradient descent':
                # Convert the *physical* positions into primed coords:
                r_old = (electron_initial_positions / L0).astype(np.float64)
                r_cur = r_old.copy()
                j = 2

                while True:
                    # compute physical gradient at r_phys = r_cur*L0
                    grad_phys = f.grad_total(r_cur * L0)          # in V/m
                    F = -(qe * grad_phys) * (L0/E0)     # dimensionless
                    max_force.append(np.max(np.abs(F)))
                    

                    # damped Verlet integration: dimensionless
                    r_next = prefactor * (F + r_cur * A - r_old * B)

                    # if j% 1000 == 0:
                    #     print('1: '+str(np.average(np.abs(r_cur*A-r_old*B))))
                    #     print('2: '+str(np.average(np.abs(F))))

                    # 4) Remove electrons out of domain in primed coords
                    x_next = r_next[::2];  y_next = r_next[1::2]
                    inside = np.logical_and.reduce((
                        x_next*L0 >= x_min, x_next*L0 <= x_max,
                        y_next*L0 >= y_min, y_next*L0 <= y_max
                    ))


                    r_next_filtered    = np.empty((2*np.sum(inside)), dtype=np.float64)
                    r_current_filtered = np.empty((2*np.sum(inside)), dtype=np.float64)

                    r_next_filtered[::2]    = x_next[inside]
                    r_next_filtered[1::2]   = y_next[inside]
                    r_current_filtered[::2] = r_cur[::2][inside]
                    r_current_filtered[1::2]= r_cur[1::2][inside]

                    # rotate for next pass
                    r_old, r_cur = r_current_filtered, r_next_filtered
                    j += 1

                    # 5) Check convergence in dimensionless force
                    if len(r_cur)==0:
                        print(f'During the convergence, no electrons left after {j} steps.')
                        break
                    
                    if np.max(np.abs(F)) < 1e-12:
                        print(f'Converged after {j} steps.')
                        r_cur = r_next_filtered
                        break

                    if j >= max_timesteps:
                        print(f'Not converged after {max_timesteps} steps.')
                        break

                # Convert *back* to physical coordinates (meters)
                equilibrium_positions = (r_cur * L0)
                


            num_electrons[k] = f.count_electrons_in_dot(equilibrium_positions, trap_bounds_x=(-1.5*1e-6,1.5*1e-6), trap_bounds_y=(-1.5*1e-6,1.5*1e-6)) #if trap_bounds_x,y is not specified, the default value is (-1e-6, 1e-6) for both x and y.
            print('There are '+str(num_electrons[k])+' electrons in the dot.')
            print(f'The maximum distance between between two iterations is {np.max(np.abs(r_cur - r_old) * 1e12):.2f} pm.')
            print(f'Max force: {max_force[-1]}')
            final_x, final_y = r2xy(equilibrium_positions)
            electron_configurations.append(equilibrium_positions)
            
            

        if N==0:
            print(f'During the voltage sweep, no electrons left after {k} steps.')
            break
        
        K, M = f.setup_eom(equilibrium_positions, resonator_dict)
        eigenfrequencies, evecs = f.solve_eom(K, M, sort_by_cavity_participation=True)
        
        if len(equilibrium_positions) > 1:
            electron_modef.append(eigenfrequencies[1])
            cavity_freqs.append(eigenfrequencies[0])
            list_of_voltages.append(voltages.copy())
            print('The cavity frequency is: ', eigenfrequencies[0])
        else:
            electron_modef.append(np.nan)  

        
        bar()
                    
    # cavity_freqs_list.append(cavity_freqs)
    # electron_modef_list.append(electron_modef)
# Out:
# on 0: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 0: Converged after 5062 steps.
# on 0: There are 5.0 electrons in the dot.
# on 0: The maximum distance between between two iterations is 0.39 pm.
# on 0: Max force: 9.553975814924342e-13
# on 0: The cavity frequency is:  799999998.1041727
# on 1: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7040201005025125), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 1: Converged after 3820 steps.
# on 1: There are 5.0 electrons in the dot.
# on 1: The maximum distance between between two iterations is 0.80 pm.
# on 1: Max force: 9.945815691025927e-13
# on 1: The cavity frequency is:  799999997.6327255
# on 2: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7080402010050251), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 2: Converged after 5421 steps.
# on 2: There are 5.0 electrons in the dot.
# on 2: The maximum distance between between two iterations is 0.30 pm.
# on 2: Max force: 9.981104085454717e-13
# on 2: The cavity frequency is:  799999996.5969468
# on 3: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7120603015075376), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 3: Converged after 15803 steps.
# on 3: There are 5.0 electrons in the dot.
# on 3: The maximum distance between between two iterations is 0.21 pm.
# on 3: Max force: 9.997456800192594e-13
# on 3: The cavity frequency is:  799999990.9516509
# on 4: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7160804020100502), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 4: Converged after 6718 steps.
# on 4: There are 5.0 electrons in the dot.
# on 4: The maximum distance between between two iterations is 0.61 pm.
# on 4: Max force: 7.680146154598332e-13
# on 4: The cavity frequency is:  799999998.0117356
# on 5: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7201005025125627), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 5: Converged after 3856 steps.
# on 5: There are 5.0 electrons in the dot.
# on 5: The maximum distance between between two iterations is 0.38 pm.
# on 5: Max force: 9.748519005370326e-13
# on 5: The cavity frequency is:  799999998.0429337
# on 6: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7241206030150753), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 6: Converged after 3905 steps.
# on 6: There are 5.0 electrons in the dot.
# on 6: The maximum distance between between two iterations is 0.27 pm.
# on 6: Max force: 9.005925676319748e-13
# on 6: The cavity frequency is:  799999998.0802056
# on 7: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7281407035175879), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 7: Converged after 3958 steps.
# on 7: There are 5.0 electrons in the dot.
# on 7: The maximum distance between between two iterations is 0.27 pm.
# on 7: Max force: 9.758446140040178e-13
# on 7: The cavity frequency is:  799999998.0996794
# on 8: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7321608040201004), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 8: Converged after 3622 steps.
# on 8: There are 5.0 electrons in the dot.
# on 8: The maximum distance between between two iterations is 1.20 pm.
# on 8: Max force: 6.991303962422535e-13
# on 8: The cavity frequency is:  799999998.1160535
# on 9: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.736180904522613), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 9: Converged after 3773 steps.
# on 9: There are 5.0 electrons in the dot.
# on 9: The maximum distance between between two iterations is 0.40 pm.
# on 9: Max force: 8.98136477189837e-13
# on 9: The cavity frequency is:  799999998.1261284
# on 10: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7402010050251255), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 10: Converged after 3828 steps.
# on 10: There are 5.0 electrons in the dot.
# on 10: The maximum distance between between two iterations is 0.35 pm.
# on 10: Max force: 8.788138075033202e-13
# on 10: The cavity frequency is:  799999998.123747
# on 11: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7442211055276382), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 11: Converged after 3881 steps.
# on 11: There are 5.0 electrons in the dot.
# on 11: The maximum distance between between two iterations is 0.39 pm.
# on 11: Max force: 9.731533054946339e-13
# on 11: The cavity frequency is:  799999998.1140406
# on 12: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7482412060301508), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 12: Converged after 4016 steps.
# on 12: There are 5.0 electrons in the dot.
# on 12: The maximum distance between between two iterations is 0.20 pm.
# on 12: Max force: 9.681953088147567e-13
# on 12: The cavity frequency is:  799999998.0958825
# on 13: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7522613065326633), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 13: Converged after 3708 steps.
# on 13: There are 5.0 electrons in the dot.
# on 13: The maximum distance between between two iterations is 0.64 pm.
# on 13: Max force: 8.78161699802149e-13
# on 13: The cavity frequency is:  799999998.0668248
# on 14: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7562814070351759), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 14: Converged after 3853 steps.
# on 14: There are 5.0 electrons in the dot.
# on 14: The maximum distance between between two iterations is 0.39 pm.
# on 14: Max force: 9.645536920288578e-13
# on 14: The cavity frequency is:  799999998.0222162
# on 15: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7603015075376884), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 15: Converged after 3994 steps.
# on 15: There are 5.0 electrons in the dot.
# on 15: The maximum distance between between two iterations is 0.22 pm.
# on 15: Max force: 9.852296898316126e-13
# on 15: The cavity frequency is:  799999997.9604722
# on 16: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.764321608040201), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 16: Converged after 3957 steps.
# on 16: There are 5.0 electrons in the dot.
# on 16: The maximum distance between between two iterations is 0.30 pm.
# on 16: Max force: 9.643808880355208e-13
# on 16: The cavity frequency is:  799999997.8576162
# on 17: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7683417085427136), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 17: Converged after 3833 steps.
# on 17: There are 5.0 electrons in the dot.
# on 17: The maximum distance between between two iterations is 0.40 pm.
# on 17: Max force: 9.991858860303181e-13
# on 17: The cavity frequency is:  799999997.6879197
# on 18: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7723618090452261), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 18: Converged after 3797 steps.
# on 18: There are 5.0 electrons in the dot.
# on 18: The maximum distance between between two iterations is 0.40 pm.
# on 18: Max force: 9.975219654734246e-13
# on 18: The cavity frequency is:  799999997.3636943
# on 19: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7763819095477387), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 19: Converged after 7657 steps.
# on 19: There are 5.0 electrons in the dot.
# on 19: The maximum distance between between two iterations is 0.25 pm.
# on 19: Max force: 9.981085895560681e-13
# on 19: The cavity frequency is:  799999996.6109034
# on 20: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7804020100502512), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 20: Converged after 42595 steps.
# on 20: There are 4.0 electrons in the dot.
# on 20: The maximum distance between between two iterations is 0.19 pm.
# on 20: Max force: 9.999239409808068e-13
# on 20: The cavity frequency is:  799999985.561992
# on 21: Unloading 5 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7844221105527638), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 21: Converged after 11390 steps.
# on 21: There are 4.0 electrons in the dot.
# on 21: The maximum distance between between two iterations is 0.40 pm.
# on 21: Max force: 9.955410860129632e-13
# on 21: The cavity frequency is:  799999998.7123553
# on 22: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7884422110552763), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 22: Converged after 4045 steps.
# on 22: There are 4.0 electrons in the dot.
# on 22: The maximum distance between between two iterations is 0.21 pm.
# on 22: Max force: 9.971788585971807e-13
# on 22: The cavity frequency is:  799999998.7079641
# on 23: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7924623115577889), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 23: Converged after 3684 steps.
# on 23: There are 3.0 electrons in the dot.
# on 23: The maximum distance between between two iterations is 0.96 pm.
# on 23: Max force: 9.046636932907857e-13
# on 23: The cavity frequency is:  799999998.7039549
# on 24: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.7964824120603015), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 24: Converged after 3823 steps.
# on 24: There are 3.0 electrons in the dot.
# on 24: The maximum distance between between two iterations is 0.59 pm.
# on 24: Max force: 9.974851309380027e-13
# on 24: The cavity frequency is:  799999998.7037344
# on 25: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.800502512562814), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 25: Converged after 3958 steps.
# on 25: There are 3.0 electrons in the dot.
# on 25: The maximum distance between between two iterations is 0.33 pm.
# on 25: Max force: 9.009006589622003e-13
# on 25: The cavity frequency is:  799999998.7007246
# on 26: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8045226130653266), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 26: Converged after 3764 steps.
# on 26: There are 3.0 electrons in the dot.
# on 26: The maximum distance between between two iterations is 0.32 pm.
# on 26: Max force: 9.595084975444479e-13
# on 26: The cavity frequency is:  799999998.6920354
# on 27: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8085427135678391), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 27: Converged after 3898 steps.
# on 27: There are 3.0 electrons in the dot.
# on 27: The maximum distance between between two iterations is 0.38 pm.
# on 27: Max force: 9.530670013191412e-13
# on 27: The cavity frequency is:  799999998.6772369
# on 28: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8125628140703517), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 28: Converged after 4033 steps.
# on 28: There are 3.0 electrons in the dot.
# on 28: The maximum distance between between two iterations is 0.21 pm.
# on 28: Max force: 9.960195939129334e-13
# on 28: The cavity frequency is:  799999998.6475307
# on 29: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8165829145728642), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 29: Converged after 4003 steps.
# on 29: There are 3.0 electrons in the dot.
# on 29: The maximum distance between between two iterations is 0.33 pm.
# on 29: Max force: 9.336597486253595e-13
# on 29: The cavity frequency is:  799999998.6126705
# on 30: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8206030150753768), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 30: Converged after 4187 steps.
# on 30: There are 3.0 electrons in the dot.
# on 30: The maximum distance between between two iterations is 0.40 pm.
# on 30: Max force: 9.985037650039886e-13
# on 30: The cavity frequency is:  799999998.5385554
# on 31: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8246231155778894), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 31: Converged after 4678 steps.
# on 31: There are 3.0 electrons in the dot.
# on 31: The maximum distance between between two iterations is 0.36 pm.
# on 31: Max force: 9.996854259952668e-13
# on 31: The cavity frequency is:  799999998.522626
# on 32: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.828643216080402), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 32: Converged after 5770 steps.
# on 32: There are 3.0 electrons in the dot.
# on 32: The maximum distance between between two iterations is 0.31 pm.
# on 32: Max force: 9.962507192540215e-13
# on 32: The cavity frequency is:  799999998.4486548
# on 33: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8326633165829145), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 33: Converged after 7002 steps.
# on 33: There are 3.0 electrons in the dot.
# on 33: The maximum distance between between two iterations is 0.28 pm.
# on 33: Max force: 9.978914476960198e-13
# on 33: The cavity frequency is:  799999998.34134
# on 34: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8366834170854272), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 34: Converged after 8688 steps.
# on 34: There are 3.0 electrons in the dot.
# on 34: The maximum distance between between two iterations is 0.27 pm.
# on 34: Max force: 9.98789005279832e-13
# on 34: The cavity frequency is:  799999998.1695001
# on 35: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8407035175879397), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 35: Converged after 11540 steps.
# on 35: There are 3.0 electrons in the dot.
# on 35: The maximum distance between between two iterations is 0.25 pm.
# on 35: Max force: 9.993231060434482e-13
# on 35: The cavity frequency is:  799999997.8238257
# on 36: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8447236180904523), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 36: Converged after 20005 steps.
# on 36: There are 3.0 electrons in the dot.
# on 36: The maximum distance between between two iterations is 0.23 pm.
# on 36: Max force: 9.997143024520483e-13
# on 36: The cavity frequency is:  799999996.817101
# on 37: Unloading 4 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8487437185929648), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 37: Converged after 21371 steps.
# on 37: There are 2.0 electrons in the dot.
# on 37: The maximum distance between between two iterations is 0.25 pm.
# on 37: Max force: 9.987968496716349e-13
# on 37: The cavity frequency is:  799999998.7662212
# on 38: Unloading 3 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8527638190954774), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 38: Converged after 9292 steps.
# on 38: There are 2.0 electrons in the dot.
# on 38: The maximum distance between between two iterations is 0.26 pm.
# on 38: Max force: 9.977470085686944e-13
# on 38: The cavity frequency is:  799999998.9464791
# on 39: Unloading 3 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8567839195979899), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 39: Converged after 6880 steps.
# on 39: There are 2.0 electrons in the dot.
# on 39: The maximum distance between between two iterations is 0.29 pm.
# on 39: Max force: 9.990203579945955e-13
# on 39: The cavity frequency is:  799999999.1257349
# on 40: Unloading 3 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8608040201005025), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 40: Converged after 5269 steps.
# on 40: There are 2.0 electrons in the dot.
# on 40: The maximum distance between between two iterations is 0.32 pm.
# on 40: Max force: 9.984207167690328e-13
# on 40: The cavity frequency is:  799999999.2275509
# on 41: Unloading 3 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8648241206030151), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 41: Converged after 18032 steps.
# on 41: There are 2.0 electrons in the dot.
# on 41: The maximum distance between between two iterations is 0.24 pm.
# on 41: Max force: 9.985992619476746e-13
# on 41: The cavity frequency is:  799999998.9624594
# on 42: Unloading 3 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8688442211055276), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 42: Converged after 14137 steps.
# on 42: There are 2.0 electrons in the dot.
# on 42: The maximum distance between between two iterations is 0.24 pm.
# on 42: Max force: 9.985169526771641e-13
# on 42: The cavity frequency is:  799999999.0592388
# on 43: Unloading 3 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8728643216080402), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 43: Converged after 20195 steps.
# on 43: There are 2.0 electrons in the dot.
# on 43: The maximum distance between between two iterations is 0.27 pm.
# on 43: Max force: 9.921261039380624e-13
# on 43: The cavity frequency is:  799999999.7737927
# on 44: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8768844221105527), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 44: Converged after 3789 steps.
# on 44: There are 2.0 electrons in the dot.
# on 44: The maximum distance between between two iterations is 0.34 pm.
# on 44: Max force: 9.99470103124622e-13
# on 44: The cavity frequency is:  799999999.7619399
# on 45: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8809045226130653), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 45: Converged after 3369 steps.
# on 45: There are 2.0 electrons in the dot.
# on 45: The maximum distance between between two iterations is 2.01 pm.
# on 45: Max force: 9.873838280327618e-13
# on 45: The cavity frequency is:  799999999.7486181
# on 46: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8849246231155778), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 46: Converged after 3524 steps.
# on 46: There are 2.0 electrons in the dot.
# on 46: The maximum distance between between two iterations is 1.05 pm.
# on 46: Max force: 9.937866707332431e-13
# on 46: The cavity frequency is:  799999999.7330966
# on 47: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8889447236180904), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 47: Converged after 3678 steps.
# on 47: There are 2.0 electrons in the dot.
# on 47: The maximum distance between between two iterations is 0.60 pm.
# on 47: Max force: 9.962795957108028e-13
# on 47: The cavity frequency is:  799999999.7156662
# on 48: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.892964824120603), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 48: Converged after 3823 steps.
# on 48: There are 2.0 electrons in the dot.
# on 48: The maximum distance between between two iterations is 0.37 pm.
# on 48: Max force: 9.974946806323714e-13
# on 48: The cavity frequency is:  799999999.6962187
# on 49: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.8969849246231155), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 49: Converged after 3366 steps.
# on 49: There are 2.0 electrons in the dot.
# on 49: The maximum distance between between two iterations is 1.90 pm.
# on 49: Max force: 9.784534995560534e-13
# on 49: The cavity frequency is:  799999999.671783
# on 50: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9010050251256281), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 50: Converged after 3679 steps.
# on 50: There are 2.0 electrons in the dot.
# on 50: The maximum distance between between two iterations is 0.67 pm.
# on 50: Max force: 9.915693226503208e-13
# on 50: The cavity frequency is:  799999999.6444585
# on 51: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9050251256281407), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 51: Converged after 3941 steps.
# on 51: There are 2.0 electrons in the dot.
# on 51: The maximum distance between between two iterations is 0.30 pm.
# on 51: Max force: 9.968944141292012e-13
# on 51: The cavity frequency is:  799999999.6034719
# on 52: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9090452261306532), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 52: Converged after 3971 steps.
# on 52: There are 2.0 electrons in the dot.
# on 52: The maximum distance between between two iterations is 0.39 pm.
# on 52: Max force: 9.980876711779273e-13
# on 52: The cavity frequency is:  799999999.5610993
# on 53: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9130653266331659), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 53: Converged after 4372 steps.
# on 53: There are 2.0 electrons in the dot.
# on 53: The maximum distance between between two iterations is 0.34 pm.
# on 53: Max force: 9.961022442439571e-13
# on 53: The cavity frequency is:  799999999.5111568
# on 54: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9170854271356783), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 54: Converged after 5583 steps.
# on 54: There are 2.0 electrons in the dot.
# on 54: The maximum distance between between two iterations is 0.28 pm.
# on 54: Max force: 9.990253602154554e-13
# on 54: The cavity frequency is:  799999999.4359733
# on 55: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.921105527638191), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 55: Converged after 7247 steps.
# on 55: There are 2.0 electrons in the dot.
# on 55: The maximum distance between between two iterations is 0.25 pm.
# on 55: Max force: 9.998184395954013e-13
# on 55: The cavity frequency is:  799999999.3016757
# on 56: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9251256281407034), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 56: Converged after 10318 steps.
# on 56: There are 2.0 electrons in the dot.
# on 56: The maximum distance between between two iterations is 0.22 pm.
# on 56: Max force: 9.991508704842998e-13
# on 56: The cavity frequency is:  799999999.0242362
# on 57: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9291457286432161), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 57: Converged after 21356 steps.
# on 57: There are 2.0 electrons in the dot.
# on 57: The maximum distance between between two iterations is 0.20 pm.
# on 57: Max force: 9.997374945669434e-13
# on 57: The cavity frequency is:  799999997.9084901
# on 58: Unloading 2 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9331658291457287), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 58: Converged after 16302 steps.
# on 58: There are 1.0 electrons in the dot.
# on 58: The maximum distance between between two iterations is 1.97 pm.
# on 58: Max force: 9.801390314367887e-13
# on 58: The cavity frequency is:  799999999.9394902
# on 59: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9371859296482412), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 59: Converged after 3286 steps.
# on 59: There are 1.0 electrons in the dot.
# on 59: The maximum distance between between two iterations is 1.64 pm.
# on 59: Max force: 9.965837203963072e-13
# on 59: The cavity frequency is:  799999999.9379297
# on 60: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9412060301507538), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 60: Converged after 2639 steps.
# on 60: There are 1.0 electrons in the dot.
# on 60: The maximum distance between between two iterations is 39.33 pm.
# on 60: Max force: 7.464156878828065e-13
# on 60: The cavity frequency is:  799999999.9367263
# on 61: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9452261306532663), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 61: Converged after 3352 steps.
# on 61: There are 1.0 electrons in the dot.
# on 61: The maximum distance between between two iterations is 1.29 pm.
# on 61: Max force: 9.68640453496289e-13
# on 61: The cavity frequency is:  799999999.9352572
# on 62: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9492462311557789), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 62: Converged after 3399 steps.
# on 62: There are 1.0 electrons in the dot.
# on 62: The maximum distance between between two iterations is 1.08 pm.
# on 62: Max force: 9.951976242114288e-13
# on 62: The cavity frequency is:  799999999.9335307
# on 63: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9532663316582914), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 63: Converged after 2796 steps.
# on 63: There are 1.0 electrons in the dot.
# on 63: The maximum distance between between two iterations is 17.97 pm.
# on 63: Max force: 7.900840181968365e-13
# on 63: The cavity frequency is:  799999999.93119
# on 64: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.957286432160804), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 64: Converged after 3516 steps.
# on 64: There are 1.0 electrons in the dot.
# on 64: The maximum distance between between two iterations is 0.69 pm.
# on 64: Max force: 9.844203915365666e-13
# on 64: The cavity frequency is:  799999999.9294137
# on 65: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9613065326633166), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 65: Converged after 3527 steps.
# on 65: There are 1.0 electrons in the dot.
# on 65: The maximum distance between between two iterations is 0.66 pm.
# on 65: Max force: 9.911071645329894e-13
# on 65: The cavity frequency is:  799999999.9282684
# on 66: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9653266331658291), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 66: Converged after 2904 steps.
# on 66: There are 1.0 electrons in the dot.
# on 66: The maximum distance between between two iterations is 11.18 pm.
# on 66: Max force: 8.75675649325558e-13
# on 66: The cavity frequency is:  799999999.9263593
# on 67: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9693467336683417), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 67: Converged after 3615 steps.
# on 67: There are 1.0 electrons in the dot.
# on 67: The maximum distance between between two iterations is 0.49 pm.
# on 67: Max force: 9.940856869061764e-13
# on 67: The cavity frequency is:  799999999.9242013
# on 68: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9733668341708542), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 68: Converged after 3676 steps.
# on 68: There are 1.0 electrons in the dot.
# on 68: The maximum distance between between two iterations is 0.41 pm.
# on 68: Max force: 9.961073045156031e-13
# on 68: The cavity frequency is:  799999999.9214289
# on 69: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9773869346733668), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 69: Converged after 3084 steps.
# on 69: There are 1.0 electrons in the dot.
# on 69: The maximum distance between between two iterations is 4.82 pm.
# on 69: Max force: 9.801982265855713e-13
# on 69: The cavity frequency is:  799999999.9196361
# on 70: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9814070351758795), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 70: Converged after 3180 steps.
# on 70: There are 1.0 electrons in the dot.
# on 70: The maximum distance between between two iterations is 3.00 pm.
# on 70: Max force: 9.983021804771396e-13
# on 70: The cavity frequency is:  799999999.9167643
# on 71: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9854271356783919), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 71: Converged after 3256 steps.
# on 71: There are 1.0 electrons in the dot.
# on 71: The maximum distance between between two iterations is 2.28 pm.
# on 71: Max force: 9.743086804500644e-13
# on 71: The cavity frequency is:  799999999.9139088
# on 72: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9894472361809046), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 72: Converged after 3345 steps.
# on 72: There are 1.0 electrons in the dot.
# on 72: The maximum distance between between two iterations is 1.56 pm.
# on 72: Max force: 9.723423635005224e-13
# on 72: The cavity frequency is:  799999999.9108295
# on 73: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.993467336683417), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 73: Converged after 3418 steps.
# on 73: There are 1.0 electrons in the dot.
# on 73: The maximum distance between between two iterations is 1.21 pm.
# on 73: Max force: 9.847851214234842e-13
# on 73: The cavity frequency is:  799999999.9079493
# on 74: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(0.9974874371859297), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 74: Converged after 3507 steps.
# on 74: There are 1.0 electrons in the dot.
# on 74: The maximum distance between between two iterations is 0.81 pm.
# on 74: Max force: 9.83159114017508e-13
# on 74: The cavity frequency is:  799999999.9045213
# on 75: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.0015075376884421), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 75: Converged after 3597 steps.
# on 75: There are 1.0 electrons in the dot.
# on 75: The maximum distance between between two iterations is 0.62 pm.
# on 75: Max force: 9.925554845802152e-13
# on 75: The cavity frequency is:  799999999.9008195
# on 76: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.0055276381909548), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 76: Converged after 3695 steps.
# on 76: There are 1.0 electrons in the dot.
# on 76: The maximum distance between between two iterations is 0.46 pm.
# on 76: Max force: 9.95958235050498e-13
# on 76: The cavity frequency is:  799999999.8963623
# on 77: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.0095477386934673), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 77: Converged after 3765 steps.
# on 77: There are 1.0 electrons in the dot.
# on 77: The maximum distance between between two iterations is 0.35 pm.
# on 77: Max force: 9.950997398033845e-13
# on 77: The cavity frequency is:  799999999.891739
# on 78: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.01356783919598), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# ...
# on 174: Converged after 3604 steps.
# on 174: There are 0.0 electrons in the dot.
# on 174: The maximum distance between between two iterations is 0.41 pm.
# on 174: Max force: 9.64342373066529e-13
# on 174: The cavity frequency is:  799999999.9571198
# on 175: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4035175879396986), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 175: Converged after 3467 steps.
# on 175: There are 0.0 electrons in the dot.
# on 175: The maximum distance between between two iterations is 1.29 pm.
# on 175: Max force: 9.233296651700583e-13
# on 175: The cavity frequency is:  799999999.9592448
# on 176: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.407537688442211), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 176: Converged after 3054 steps.
# on 176: There are 0.0 electrons in the dot.
# on 176: The maximum distance between between two iterations is 4.10 pm.
# on 176: Max force: 3.948182296653612e-13
# on 176: The cavity frequency is:  799999999.9592448
# on 177: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4115577889447235), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 177: Converged after 3783 steps.
# on 177: There are 0.0 electrons in the dot.
# on 177: The maximum distance between between two iterations is 0.22 pm.
# on 177: Max force: 9.36627678527202e-13
# on 177: The cavity frequency is:  799999999.9581823
# on 178: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4155778894472362), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 178: Converged after 3020 steps.
# on 178: There are 0.0 electrons in the dot.
# on 178: The maximum distance between between two iterations is 4.72 pm.
# on 178: Max force: 7.096654144334024e-13
# on 178: The cavity frequency is:  799999999.9592448
# on 179: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4195979899497488), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 179: Converged after 2963 steps.
# on 179: There are 0.0 electrons in the dot.
# on 179: The maximum distance between between two iterations is 6.28 pm.
# on 179: Max force: 9.510641874044268e-14
# on 179: The cavity frequency is:  799999999.9581823
# on 180: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4236180904522613), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 180: Converged after 3260 steps.
# on 180: There are 0.0 electrons in the dot.
# on 180: The maximum distance between between two iterations is 1.42 pm.
# on 180: Max force: 9.540071168601117e-13
# on 180: The cavity frequency is:  799999999.9592448
# on 181: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4276381909547737), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 181: Converged after 2850 steps.
# on 181: There are 0.0 electrons in the dot.
# on 181: The maximum distance between between two iterations is 10.92 pm.
# on 181: Max force: 1.661634563276948e-13
# on 181: The cavity frequency is:  799999999.9592448
# on 182: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4316582914572864), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 182: Converged after 3544 steps.
# on 182: There are 0.0 electrons in the dot.
# on 182: The maximum distance between between two iterations is 0.68 pm.
# on 182: Max force: 9.779611112037402e-13
# on 182: The cavity frequency is:  799999999.9592448
# on 183: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.435678391959799), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 183: Converged after 3142 steps.
# on 183: There are 0.0 electrons in the dot.
# on 183: The maximum distance between between two iterations is 2.53 pm.
# on 183: Max force: 9.669225298214457e-13
# on 183: The cavity frequency is:  799999999.9592448
# on 184: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4396984924623117), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 184: Converged after 3595 steps.
# on 184: There are 0.0 electrons in the dot.
# on 184: The maximum distance between between two iterations is 0.57 pm.
# on 184: Max force: 7.508437285252967e-13
# on 184: The cavity frequency is:  799999999.9613696
# on 185: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4437185929648242), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 185: Converged after 2749 steps.
# on 185: There are 0.0 electrons in the dot.
# on 185: The maximum distance between between two iterations is 17.14 pm.
# on 185: Max force: 3.53966363775271e-13
# on 185: The cavity frequency is:  799999999.962432
# on 186: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4477386934673366), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 186: Converged after 3544 steps.
# on 186: There are 0.0 electrons in the dot.
# on 186: The maximum distance between between two iterations is 0.88 pm.
# on 186: Max force: 9.338576916206876e-13
# on 186: The cavity frequency is:  799999999.9613696
# on 187: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4517587939698493), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 187: Converged after 3723 steps.
# on 187: There are 0.0 electrons in the dot.
# on 187: The maximum distance between between two iterations is 0.48 pm.
# on 187: Max force: 8.038787615571863e-13
# on 187: The cavity frequency is:  799999999.962432
# on 188: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.455778894472362), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 188: Converged after 3424 steps.
# on 188: There are 0.0 electrons in the dot.
# on 188: The maximum distance between between two iterations is 0.60 pm.
# on 188: Max force: 9.683040175789693e-13
# on 188: The cavity frequency is:  799999999.962432
# on 189: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4597989949748744), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 189: Converged after 3286 steps.
# on 189: There are 0.0 electrons in the dot.
# on 189: The maximum distance between between two iterations is 2.44 pm.
# on 189: Max force: 3.588437436224945e-13
# on 189: The cavity frequency is:  799999999.9613696
# on 190: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4638190954773869), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 190: Converged after 3697 steps.
# on 190: There are 0.0 electrons in the dot.
# on 190: The maximum distance between between two iterations is 0.53 pm.
# on 190: Max force: 8.936140914184154e-13
# on 190: The cavity frequency is:  799999999.9634945
# on 191: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4678391959798995), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 191: Converged after 2908 steps.
# on 191: There are 0.0 electrons in the dot.
# on 191: The maximum distance between between two iterations is 7.73 pm.
# on 191: Max force: 2.1412352041449978e-13
# on 191: The cavity frequency is:  799999999.9634945
# on 192: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4718592964824122), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 192: Converged after 2853 steps.
# on 192: There are 0.0 electrons in the dot.
# on 192: The maximum distance between between two iterations is 10.12 pm.
# on 192: Max force: 7.471157115190862e-13
# on 192: The cavity frequency is:  799999999.9645568
# on 193: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4758793969849247), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 193: Converged after 3576 steps.
# on 193: There are 0.0 electrons in the dot.
# on 193: The maximum distance between between two iterations is 0.64 pm.
# on 193: Max force: 9.020004947402072e-13
# on 193: The cavity frequency is:  799999999.962432
# on 194: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.479899497487437), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 194: Converged after 3587 steps.
# on 194: There are 0.0 electrons in the dot.
# on 194: The maximum distance between between two iterations is 0.40 pm.
# on 194: Max force: 7.541679094558162e-13
# on 194: The cavity frequency is:  799999999.9634945
# on 195: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4839195979899498), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 195: Converged after 3236 steps.
# on 195: There are 0.0 electrons in the dot.
# on 195: The maximum distance between between two iterations is 1.51 pm.
# on 195: Max force: 3.346124710407357e-13
# on 195: The cavity frequency is:  799999999.9645568
# on 196: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4879396984924624), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 196: Converged after 3033 steps.
# on 196: There are 0.0 electrons in the dot.
# on 196: The maximum distance between between two iterations is 4.14 pm.
# on 196: Max force: 8.387130488300177e-13
# on 196: The cavity frequency is:  799999999.9645568
# on 197: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4919597989949749), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 197: Converged after 3224 steps.
# on 197: There are 0.0 electrons in the dot.
# on 197: The maximum distance between between two iterations is 1.59 pm.
# on 197: Max force: 2.372488297343149e-13
# on 197: The cavity frequency is:  799999999.9634945
# on 198: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.4959798994974873), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 198: Converged after 3634 steps.
# on 198: There are 0.0 electrons in the dot.
# on 198: The maximum distance between between two iterations is 0.81 pm.
# on 198: Max force: 9.544674295369758e-13
# on 198: The cavity frequency is:  799999999.9656193
# on 199: Unloading 1 electrons with voltages: {'half_donut_top': 0.2, 'half_donut_bottom': -0.5, 'gate_top': np.float64(1.5), 'gate_bottom': -0.5, 'reservoir': -0.5, 'center': 0.0, 'guard': 0.0}
# on 199: Converged after 3533 steps.
# on 199: There are 0.0 electrons in the dot.
# on 199: The maximum distance between between two iterations is 0.30 pm.
# on 199: Max force: 7.507045678423196e-13
# on 199: The cavity frequency is:  799999999.9666818
# |████████████████████████████████████████| 200/200 [100%] in 2:25.2 (1.37/s)

# %%
f0_list = [0.120945e9, 0.400e9, 0.600e9, 0.800e9]

# %%
print(electron_initial_positions)
print(equilibrium_positions)
print(r_cur)
print((electron_initial_positions / L0).astype(np.float64))  
print(N)
# Out:
# [-4.52320000e-06  1.57975653e-07]
# [-4.52320000e-06  1.57975653e-07]
# []
# [-4.5232      0.15797565]
# 1

# %% [markdown]
# ### Animates the voltage sweep

# %%
fig, ax = plt.subplots(figsize=(7, 4.))
print(len(list_of_voltages))
print(len(electron_configurations))
anim = f.animate_voltage_sweep(fig, ax,  list_of_voltages=list_of_voltages, list_of_electron_positions=electron_configurations,
                            dxdy=(10, 8), frame_interval_ms=200 )
ax.set_xlim(-5, 1.9)
f.show_animation(anim)
# Out:
# 200
# 200
# <video width="700" height="400" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Plot the number of electrons and the frequency shifts

# %%
from scipy.signal import find_peaks

y=f0*np.ones(len(cavity_freqs))-cavity_freqs 

peaks, prop = find_peaks(y,
                          height=None,    # ou valeur minimale : height=0.1
                          distance=10,    # écart minimal entre pics
                          prominence=1 # proéminence minima
                         )
idx=np.sort(peaks[:5])

print(unload_voltages[idx[0:5]])
# Out:
# [0.7120603  0.78040201 0.84472362 0.92914573 1.07788945]

# %%
# %matplotlib inline


fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(14, 5), sharex=True)

# ==== Left subplot ====
ax1.step(unload_voltages, num_electrons, label="Number of electrons", color='tab:blue')
ax1.set_xlabel("Top and bottom gate voltage [V]")
ax1.set_ylabel("Number of electrons")

ax2 = ax1.twinx()
ax2.plot(unload_voltages, cavity_freqs - f0*np.ones(len(cavity_freqs)), 'r--', label="Cavity frequency shift")
for k in range(5):
    ax2.vlines(unload_voltages[idx[k]], 0, cavity_freqs[idx[k]]-f0, colors='green', linestyles='--')
ax2.set_ylabel("Cavity frequency shift [Hz]")
ax2.spines["right"].set_position(("axes", 1.1))

# Legend for left subplot at bottom left
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='lower left', frameon=False)


# ==== Right subplot ====
ax3.step(unload_voltages, num_electrons, label="Number of electrons", color='tab:blue')
ax3.set_xlabel("Top and bottom gate voltage [V]")
ax3.set_ylabel("Number of electrons")

ax4 = ax3.twinx()
ax4.plot(unload_voltages, electron_modef, 'g--', label="First electron mode frequency")
ax4.set_ylabel("First electron mode frequency [Hz]")
ax4.spines["right"].set_position(("axes", 1.1))

# Legend for right subplot at bottom left
lines3, labels3 = ax3.get_legend_handles_labels()
lines4, labels4 = ax4.get_legend_handles_labels()
ax3.legend(lines3 + lines4, labels3 + labels4, loc='lower left', frameon=False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Animation of the modes that couple the most to the AC electric field

# %%
fig, ax = plt.subplots(3, 5, figsize=(5* 4., 3*4), constrained_layout=True)


colors=['white', 'gray', 'black']
anim=[]
f= {i: None for i in range(5)}

voltages = {
    'half_donut_top':0.2,
    'half_donut_bottom':-0.5,
    'gate_top':0.0,
    'gate_bottom':-0.5,
    'reservoir':-0.5,
    'center':0.0,
    'guard':0.0,
}


for k in range(5):
    unload_voltage=unload_voltages[idx[k]]
    equilibrium_positions=electron_configurations[idx[k]]
    voltages['gate_top'] = unload_voltage
    print('Vgate='+str(unload_voltage))
    f[k] = FullModel(trap.dot, voltages, **options)
    f[k].set_rf_interpolator(rf_electrode_labels=['guard'])
    K, M = f[k].setup_eom(equilibrium_positions, resonator_dict)
    eigenfrequencies, evecs = f[k].solve_eom(K, M, sort_by_cavity_participation=True)
    res={'x': equilibrium_positions}
    for j in range(3):
        f[k].plot_potential_energy(ax=ax[j,k], coor=[0, 0], dxdy=(5, 8), print_voltages=False, plot_contours=False)
        ax[j,k].set_xlim(-2.5, 2)
        # f.plot_electron_positions(res=res,ax=ax[k,j])
        ax[j,k].set_title(f"{eigenfrequencies[j]/1e9:.2f} GHz")
        f[k].plot_eigenvector(equilibrium_positions, evecs[:, j], length=1.5, color='black', ax=ax[j,k])
    anim.append(f[k].animate_eigenvectors(fig, ax[:,k], eigenvector_list=evecs.T, electron_positions=equilibrium_positions, 
                            amplitude=0.25e-6))


# fig.tight_layout()
# anim = f.animate_eigenvectors(fig, ax, eigenvector_list=evecs.T, electron_positions=res['x'],
#                               amplitude=0.25e-6)
# Out:
# Vgate=0.7120603015075376
# Vgate=0.7804020100502512
# Vgate=0.8447236180904523
# Vgate=0.9291457286432161
# Vgate=1.0778894472361809

# %%
f[0].show_animation(anim[2])
# Out:
# <video width="1800" height="1000" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
fig, ax = plt.subplots(figsize=(7, 5))
cavity_freqs_list = np.array(cavity_freqs_list)

# Tracer les shifts de fréquence pour chaque courbe
for i, cavity_freqs in enumerate(cavity_freqs_list):
# for i in range(len(f0_list)):
    label = f"f0 = {f0_list[i]*1e-9:.2f} GHz"
    ax.plot(unload_voltages, cavity_freqs - f0_list[i]*np.ones(len(cavity_freqs)), '--', label=label)

# Axe et titre
ax.set_xlabel("Top and bottom gate voltage [V]")
ax.set_ylabel("Cavity frequency shift [Hz]")
ax.legend(loc='lower left', frameon=False)

plt.tight_layout()
plt.show()
