# %%
import matplotlib.pyplot as plt
import numpy as np
import os, sys, alive_progress

from quantum_electron.electron_counter import FullModel, make_potential, find_minimum_location
from quantum_electron.schrodinger_solver import QuantumAnalysis
from quantum_electron.utils import xy2r, r2xy, crop_potential, find_nearest,  density_from_positions, select_outer_electrons, find_minimum_location

from zeroheliumkit.src.importing import Reader_DXF
from zeroheliumkit.fem import FieldAnalyzer
from zeroheliumkit.src.settings import *
import matplotlib.animation as animation

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

plot_config = {"anchors": CYAN,
               "0": BLUE,
               "EBEAMLITHO_GUARDS": ORANGE,
               "EBEAMLITHO_SMALLPADS": RED,
               "Pillar0": GREEN}
import zeroheliumkit 
from scipy.constants import elementary_charge as qe, epsilon_0 as eps0, electron_mass as me, Boltzmann as kB
from matplotlib import patheffects as pe
import random

# %% [markdown]
# ## Download the potential

# %%
dirname = 'sim_test/'
device = zeroheliumkit.GeomCollection(layers=Reader_DXF(r"./sim_test/sample_resevoir_10x10_no_bond_lines.dxf").geometries)
device.quickplot(plot_config)
trap = FieldAnalyzer((dirname+'phi_xy.txt', 'dot', '2Dmap'))
# Out:
# ./sim_test/sample_resevoir_10x10_no_bond_lines.dxf // Layers : dict_keys(['EBEAMLITHO_SMALLPADS', '0', 'EBEAMLITHO_GUARDS'])

# %%
print(f"Input data dx = {np.diff(trap.dot['xlist'])[0] * 1e3:.1f} nm")
print(f"Input data dy = {np.diff(trap.dot['ylist'])[0] * 1e3:.1f} nm")
# Out:
# Input data dx = 20.0 nm
# Input data dy = 20.0 nm

# %% [markdown]
# ## Choose the voltages
# typical charge noise 100 uV (GaAs @Delft) 230 uV(Si @Delft) 70 uV (best Si) 8 uV (best GaAs)
#
# These values are dominated by the devices themselves, not from the electronics.

# %%
from quantum_electron.utils import crop_potential

voltages = {
    'half_donut_top':0.5,
    'half_donut_bottom':0.5,
    'gate_top':0.2,
    'gate_bottom':0.2,
    'reservoir':0.7,
    'center':0.6,
    'guard':-0.000,
}

for electrode in trap.dot.keys():
    if electrode == 'xlist' or electrode == 'ylist':
        break
    new_x, new_y, new_U = crop_potential(x=trap.dot['xlist'], y=trap.dot['ylist'], U=trap.dot[electrode],
                                         xrange=(-5, 2), yrange=(-4,4))

    trap.dot[electrode] = new_U

trap.dot['xlist'] = new_x
trap.dot['ylist'] = new_y

# %%
fig, ax = plt.subplots()
fm = FullModel(trap.dot, voltages)
fm.plot_potential_energy(ax=ax, coor=[0,0], dxdy=(10, 8))
ax.set_xlim(-5, 2)
# Out:
# (-5.0, 2.0)

# %%
qa = QuantumAnalysis(trap.dot, voltages)

qa.plot_potential_energy(coor=(0, 0), dxdy=(3, 3))

# %%
 #Returns the frequencies of the first N=6 eigenmodes for a single electron trapped in a potential. 
single_electron_frequencies = qa.get_quantum_spectrum(coor=(0, 0), dxdy=(2.9, 2.9), plot_wavefunctions=True, axes_zoom=1, n_x=201, n_y=201)
# here the energy splitting between first and excited is higher than with the same script on box because the S. equation is solved on a larger interval
# Out:
# max_ysol:1.45
# y_com_max:0.4994218338561656
# max_ysol:1.45
# y_com_max:0.49943315808236316
# max_ysol:1.45
# y_com_max:0.4994002965587594
# max_ysol:1.45
# y_com_max:0.49942041219400435
# max_ysol:1.45
# y_com_max:0.49943646414742665
# max_ysol:1.45
# y_com_max:0.49935427645468344

# %% [markdown]
# ## Test voltage configuration

# %% [markdown]
# ### Calculate electrons equilibrium positions

# %%
import numpy as np
import matplotlib.pyplot as plt

# Conversion en float64 des bornes
x_min = np.float64(np.min(trap.dot['xlist']) * 1e-6)
x_max = np.float64(np.max(trap.dot['xlist']) * 1e-6)
y_min = np.float64(np.min(trap.dot['ylist']) * 1e-6)
y_max = np.float64(np.max(trap.dot['ylist']) * 1e-6)

voltages = {
    'half_donut_top':0.05,
    'half_donut_bottom':0.05,
    'gate_top':0.02,
    'gate_bottom':0.02,
    'reservoir':0.05,
    'center':0,
    'guard':0.000,
}

options = { "include_screening" : False, # Include screening of electron-electron interactions due to thin film.
           "screening_length" : np.inf, # Typically helium thickness.
           "potential_smoothing" : 1e-5, # Numerical smoothing of the splines (gets rid of some noise, can introduce artifacts)
           "remove_unbound_electrons" : False, # Removes electrons if they shot outside the solution box.
           "remove_bounds" : None, # Sets which electrons should be removed if above is True.
           "trap_annealing_steps" : [0.1] * 10, # List of annealing temperatures, length determines the number of steps
           "max_x_displacement" : 0.1e-6, # Maximum x-displacement of solved electron positions during annealing.
           "max_y_displacement" : 0.1e-6} # Maximum y-displacement of solved electron positions during annealing.


plot_initial_condition = True
convergence_method = 'Physical gradient descent'
Nmax = 5
energies = np.zeros(Nmax-1, dtype=np.float64)
max_force = []


# Dimensionless rescaling
# -------------------------
# Base units (SI → dimensionless)
L0 = 1e-6                      # 1 μm in meters
E0 = qe                        # 1 eV in joules
M0 = me                        # electron mass in kg
Q0 = qe                        # elementary charge in C
T0 = L0 * np.sqrt(M0/E0)      # derived time unit

# Convert your physical timestep into dimensionless dt
dt_phys = 1e-13                # your original dt in seconds
dt = np.float64(dt_phys / T0)  # dimensionless

# Now redefine your usual Verlet coefficients in *this* dt
gamma    = np.float64(-0.01) / dt
prefactor= np.float64(1.0) / (1.0/dt**2 - gamma/dt)
A        = np.float64(2.0/dt**2 - gamma/dt)
B        = np.float64(1.0/dt**2)

max_timesteps = 500000# Maximum number of timesteps for the convergence method


for N in [5]:
    f = FullModel(trap.dot, voltages, **options)
    f.remove_unbound_electrons = False

    initial_condition = f.generate_initial_condition(N, center=[0, 0], radius=np.float64(0.1e-6))
    init_x, init_y = r2xy(initial_condition)

    if convergence_method == 'L-BFGS-B':
        f.trap_annealing_steps = [0.5] * 30
        res = f.get_electron_positions(n_electrons=N, electron_initial_positions=initial_condition,
                                       verbose=False, gradient_tolerance=1e-9, ftol=1e-300)
        equilibrium_positions = res['x']

    elif convergence_method == 'Physical gradient descent':
        # Convert the *physical* positions into primed coords:
        r_old = (initial_condition / L0).astype(np.float64)
        r_cur = r_old.copy()
        j = 2

        while True:
            # 1) compute physical gradient at r_phys = r_cur*L0
            grad_phys = f.grad_total(r_cur * L0)          # in V/m
            # 2) F_phys = -qe * grad_phys (J/m), convert to dimensionless:
            F = -(qe * grad_phys) * (L0/E0)     # dimensionless
            max_force.append(np.max(np.abs(F)))

            # 3) Verlet‐damped update (dimensionless)
            r_next = prefactor * (F + r_cur * A - r_old * B)

            # 4) Remove electrons out of domain in primed coords
            x_next = r_next[::2];  y_next = r_next[1::2]
            inside = np.logical_and.reduce((
                x_next*L0 >= x_min, x_next*L0 <= x_max,
                y_next*L0 >= y_min, y_next*L0 <= y_max
            ))


            r_next_filtered    = np.empty((2*np.sum(inside)), dtype=np.float64)
            r_current_filtered = np.empty((2*np.sum(inside)), dtype=np.float64)

            r_next_filtered[::2]    = x_next[inside]
            r_next_filtered[1::2]   = y_next[inside]
            r_current_filtered[::2] = r_cur[::2][inside]
            r_current_filtered[1::2]= r_cur[1::2][inside]

            # rotate for next pass
            r_old, r_cur = r_current_filtered, r_next_filtered
            j += 1

            if len(r_cur)==0:
                print(f'During the convergence, no electrons left after {j} steps.')
                break
            
            # 5) Check convergence in dimensionless force
            if np.max(np.abs(F)) < 1e-12:
                print(f'Converged after {j} steps.')
                r_cur = r_next_filtered
                break

            if j >= max_timesteps:
                print(f'Not converged after {max_timesteps} steps.')
                break

        # Convert *back* to physical coordinates (meters)
        equilibrium_positions = (r_cur * L0)
        print(max_force[-1])



    print(f'The distance between the last two iterations is {np.linalg.norm(r_cur - r_old) * 1e6:.2f} um.')

    final_x, final_y = r2xy(equilibrium_positions)
    number_electron = f.count_electrons_in_dot(equilibrium_positions,
                                               trap_bounds_x=(-2e-6, 2e-6),
                                               trap_bounds_y=(-2e-6, 2e-6))
    print(f'There are {number_electron} electrons in the dot.')

    fig, ax = plt.subplots()
    f.plot_potential_energy(coor=[0, 0], dxdy=(10, 8), ax=ax)
    res = {'x': equilibrium_positions}
    f.plot_electron_positions(res)
    ax.set_xlim(-5, 2)

    if plot_initial_condition:
        plt.plot(init_x * 1e6, init_y * 1e6, 'or', ms=3)
# Out:
# Converged after 30845 steps.
# 9.997109715609297e-13
# The distance between the last two iterations is 0.00 um.
# There are 2 electrons in the dot.

# %%
fig, ax = plt.subplots()
ax.scatter(range(len(max_force)), max_force, s=1, c='k', label='Norm of the force')
ax.set_xlabel('Time step')
ax.set_ylabel('Norm of gradient')
# ax.set_ylim(0, 3e-13)
ax.legend()

print(f"Electron positions: x_min={x_min:.2e}, x_max={x_max:.2e}, y_min={y_min:.2e}, y_max={y_max:.2e}")
if np.any(final_x < x_min) or np.any(final_x > x_max) or np.any(final_y < y_min) or np.any(final_y > y_max):
    print("Electron outside potential grid!")

print(np.finfo(np.float64).eps)
# Out:
# Electron positions: x_min=-5.00e-06, x_max=1.98e-06, y_min=-4.00e-06, y_max=3.98e-06
# 2.220446049250313e-16

# %% [markdown]
# ### Setup EOM

# %%
Vrms = 140e-9
f0 = 0.8e9

Z = 2 / 1.055e-34 * (Vrms / (2 * np.pi * f0)) ** 2

resonator_dict = {"f0" : f0, # Resonance frequency for the resonator (only used for solving motional frequencies)
                  "Z0" : Z} # Resonator impedance (only used for solving motional frequencies)

# %%
f.set_rf_interpolator(rf_electrode_labels=['center'])
# solves the equations of motion  
K, M = f.setup_eom(res['x'], resonator_dict=resonator_dict)
# added: resonator_dict=resonator_dict
eigenfrequencies, evecs = f.solve_eom(K, M, sort_by_cavity_participation=True, filter_nan=True)
print(f"Eigenfrequencies: {eigenfrequencies}")
# Out:
# Eigenfrequencies: [7.99999992e+08 1.37537905e+10 7.08914038e+09 1.33991528e+10
#  6.73764093e+09]

# %% [markdown]
# ### AC electric field

# %%
X, Y = np.meshgrid(trap.dot['xlist'] * 1e-6, trap.dot['ylist'] * 1e-6)

Ex = f.Ex(X, Y)
Ey = f.Ey(X, Y)

fig = plt.figure(figsize=(5, 4.))
plt.pcolormesh(X * 1e6, Y * 1e6, Ex / 1e6, cmap=plt.cm.RdBu, vmax=0.5, vmin=-0.5)
cbar = plt.colorbar()
cbar.ax.set_ylabel(f"$E_x$ (V/{chr(956)}m)")
plt.xlabel(rf"$x$ ({chr(956)}m)")
plt.ylabel(rf"$y$ ({chr(956)}m)")
plt.gca().set_aspect('equal')

fig = plt.figure(figsize=(5, 4.))
plt.pcolormesh(X * 1e6, Y * 1e6, Ey / 1e6, cmap=plt.cm.RdBu, vmax=0.5, vmin=-0.5)
cbar = plt.colorbar()
cbar.ax.set_ylabel(f"$E_y$ (V/{chr(956)}m)")
plt.xlabel(rf"$x$ ({chr(956)}m)")
plt.ylabel(rf"$y$ ({chr(956)}m)")
plt.gca().set_aspect('equal')

# %%
fig, ax = plt.subplots(1, 3, figsize=(3 * 3., 4.))

for k in range(3):
    f.plot_potential_energy(ax=ax[k], coor=[0, 0], dxdy=(3, 3), print_voltages=False)
    ax[k].set_title(f"{eigenfrequencies[k]/1e9:.2f} GHz")
    # f.plot_electron_positions(res)

    # f.plot_eigenvector(res['x'], evecs[:, 2], color='white')
    # f.plot_eigenvector(res['x'], evecs[:, 1], color='gray')

fig.tight_layout()
anim = f.animate_eigenvectors(fig, ax, eigenvector_list=evecs.T, electron_positions=res['x'],
                              amplitude=0.25e-6)

# %%
f.show_animation(anim)
# Out:
# <video width="900" height="400" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
f.save_animation(anim, filepath="./single_electron_very_small_voltages.gif")

# %% [markdown]
# ### Voltage sweep 1

# %%
voltages = {
    'half_donut_top':0.00,
    'half_donut_bottom':0.00,
    'gate_top':-0.00,
    'gate_bottom':0.0,
    'reservoir':0.000,
    'center':0.01,
    'guard':0.000,
}

options = { "include_screening" : False, # Include screening of electron-electron interactions due to thin film.
           "screening_length" : np.inf, # Typically helium thickness.
           "potential_smoothing" : 1e-5, # Numerical smoothing of the splines (gets rid of some noise, can introduce artifacts)
           "remove_unbound_electrons" : False, # Removes electrons if they shot outside the solution box.
           "remove_bounds" : None, # Sets which electrons should be removed if above is True.
           "trap_annealing_steps" : [0.1] * 10, # List of annealing temperatures, length determines the number of steps
           "max_x_displacement" : 0.1e-6, # Maximum x-displacement of solved electron positions during annealing.
           "max_y_displacement" : 0.1e-6} # Maximum y-displacement of solved electron positions during annealing.

use_previous_initial_state = True # If True, use the previous equilibrium positions as initial condition for the next voltage sweep.

list_of_voltages = []
num_electrons=[]
electron_configurations=[]
sweep_voltages = np.linspace(0, 0.02, 101)

# if you put N electrons, you have 2N+1 eigenfrequencies
eigenfrequencies = np.zeros((len(sweep_voltages), 3))
plot = True

convergence_method='Physical gradient descent' # 'L-BFGS-B' or 'Physical gradient descent'


# Dimensionless rescaling
# -------------------------
# Base units (SI → dimensionless)
L0 = 1e-6                      # 1 μm in meters
E0 = qe                        # 1 eV in joules
M0 = me                        # electron mass in kg
Q0 = qe                        # elementary charge in C
T0 = L0 * np.sqrt(M0/E0)      # derived time unit

# Convert your physical timestep into dimensionless dt
dt_phys = 1e-13                # your original dt in seconds
dt = np.float64(dt_phys / T0)  # dimensionless

# Now redefine your usual Verlet coefficients in *this* dt
gamma    = np.float64(-0.01) / dt
prefactor= np.float64(1.0) / (1.0/dt**2 - gamma/dt)
A        = np.float64(2.0/dt**2 - gamma/dt)
B        = np.float64(1.0/dt**2)

max_timesteps = 500000# Maximum number of timesteps for the convergence method

N_init=1

with alive_progress.alive_bar(len(sweep_voltages), force_tty=True) as bar:
    for k, center in enumerate(sweep_voltages):

        voltages["half_donut_top"] = center
        voltages["half_donut_bottom"] = center
        


        f = FullModel(trap.dot, voltages, **options)


        f.set_rf_interpolator(rf_electrode_labels=['guard'])

        if k == 0: 
            electron_initial_positions = f.generate_initial_condition(N_init, center=(0, 0), radius=0.1e-6)
            N = N_init
        elif use_previous_initial_state: 
            electron_initial_positions = equilibrium_positions
            N = len(electron_initial_positions) // 2
        else:
            electron_initial_positions = None
            N = N_init
        
        
        if N > 0:
            print(f'Unloading {N} electrons with voltages: {voltages}')
            max_force=[]
            if convergence_method == 'L-BFGS-B':
                res = f.get_electron_positions(n_electrons=N, 
                                            electron_initial_positions=electron_initial_positions, 
                                            verbose=False, 
                                            suppress_warnings=False)
                equilibrium_positions = res['x']

    

            if convergence_method == 'Physical gradient descent':
                # Convert the *physical* positions into primed coords:
                r_old = (electron_initial_positions / L0).astype(np.float64)
                r_cur = r_old.copy()
                j = 2

                while True:
                    # compute physical gradient at r_phys = r_cur*L0
                    grad_phys = f.grad_total(r_cur * L0)          # in V/m
                    F = -(qe * grad_phys) * (L0/E0)     # dimensionless
                    max_force.append(np.max(np.abs(F)))
                     

                    # damped Verlet integration: dimensionless
                    r_next = prefactor * (F + r_cur * A - r_old * B)

                    # if j% 1000 == 0:
                    #     print('1: '+str(np.average(np.abs(r_cur*A-r_old*B))))
                    #     print('2: '+str(np.average(np.abs(F))))

                    # 4) Remove electrons out of domain in primed coords
                    x_next = r_next[::2];  y_next = r_next[1::2]
                    inside = np.logical_and.reduce((
                        x_next*L0 >= x_min, x_next*L0 <= x_max,
                        y_next*L0 >= y_min, y_next*L0 <= y_max
                    ))


                    r_next_filtered    = np.empty((2*np.sum(inside)), dtype=np.float64)
                    r_current_filtered = np.empty((2*np.sum(inside)), dtype=np.float64)

                    r_next_filtered[::2]    = x_next[inside]
                    r_next_filtered[1::2]   = y_next[inside]
                    r_current_filtered[::2] = r_cur[::2][inside]
                    r_current_filtered[1::2]= r_cur[1::2][inside]

                    # rotate for next pass
                    r_old, r_cur = r_current_filtered, r_next_filtered

                    j += 1

                    # 5) Check convergence in dimensionless force
                    if len(r_cur)==0:
                        print(f'During the convergence, no electrons left after {j} steps.')
                        break
                       
                    if np.max(np.abs(F)) < 1e-13:
                        print(f'Converged after {j} steps.')
                        r_cur = r_next_filtered
                        break


                    if j >= max_timesteps:
                        print(f'Not converged after {max_timesteps} steps.')
                        break

                # Convert *back* to physical coordinates (meters)
                equilibrium_positions = (r_cur * L0)
                print(np.linalg.norm(r_cur-r_old))
                print(max_force[-1])


            num_electrons.append(f.count_electrons_in_dot(equilibrium_positions, trap_bounds_x=(-1.5*1e-6,1.5*1e-6), trap_bounds_y=(-1.5*1e-6,1.5*1e-6))) #if trap_bounds_x,y is not specified, the default value is (-1e-6, 1e-6) for both x and y.
            print('There are '+str(num_electrons[k])+' electrons in the dot.')
            final_x, final_y = r2xy(equilibrium_positions)
            electron_configurations.append(equilibrium_positions)
            list_of_voltages.append(voltages.copy())
    

        K, M = f.setup_eom(equilibrium_positions, resonator_dict=resonator_dict)
        eigenfrequencies[k, :], evecs = f.solve_eom(K, M, sort_by_cavity_participation=True)

        bar()




plt.figure()
plt.plot(sweep_voltages, eigenfrequencies / 1e9)
plt.xlabel(" Voltages (V)")
plt.ylabel("Frequency (GHz)")
plt.xlim(np.min(sweep_voltages), np.max(sweep_voltages))
# Out:
# on 0: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0), 'half_donut_bottom': np.float64(0.0), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 0: Converged after 3950 steps.
# on 0: 2.543969809377951e-12
# on 0: 7.265380103094188e-14
# on 0: There are 1 electrons in the dot.
# on 1: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0002), 'half_donut_bottom': np.float64(0.0002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 1: Converged after 4056 steps.
# on 1: 5.0146330203994865e-14
# on 1: 9.984818527541962e-14
# on 1: There are 1 electrons in the dot.
# on 2: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0004), 'half_donut_bottom': np.float64(0.0004), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 2: Converged after 3794 steps.
# on 2: 3.394236974141684e-13
# on 2: 9.947450335667795e-14
# on 2: There are 1 electrons in the dot.
# on 3: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0006000000000000001), 'half_donut_bottom': np.float64(0.0006000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 3: Converged after 3931 steps.
# on 3: 3.9257917775114976e-14
# on 3: 9.958100777307521e-14
# on 3: There are 1 electrons in the dot.
# on 4: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0008), 'half_donut_bottom': np.float64(0.0008), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 4: Converged after 3894 steps.
# on 4: 5.0724166915873896e-14
# on 4: 9.91914514969494e-14
# on 4: There are 1 electrons in the dot.
# on 5: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.001), 'half_donut_bottom': np.float64(0.001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 5: Converged after 3819 steps.
# on 5: 6.245939392279845e-14
# on 5: 9.990518928804092e-14
# on 5: There are 1 electrons in the dot.
# on 6: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0012000000000000001), 'half_donut_bottom': np.float64(0.0012000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 6: Converged after 4131 steps.
# on 6: 2.726470583783819e-14
# on 6: 9.948549895000267e-14
# on 6: There are 1 electrons in the dot.
# on 7: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0014), 'half_donut_bottom': np.float64(0.0014), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 7: Converged after 4532 steps.
# on 7: 3.185318922018991e-14
# on 7: 9.962129438045864e-14
# on 7: There are 1 electrons in the dot.
# on 8: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0016), 'half_donut_bottom': np.float64(0.0016), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 8: Converged after 3882 steps.
# on 8: 3.606366238958741e-14
# on 8: 9.932825761893582e-14
# on 8: There are 1 electrons in the dot.
# on 9: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0018000000000000002), 'half_donut_bottom': np.float64(0.0018000000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 9: Converged after 4672 steps.
# on 9: 3.038647681566793e-14
# on 9: 9.967951047906708e-14
# on 9: There are 1 electrons in the dot.
# on 10: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.002), 'half_donut_bottom': np.float64(0.002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 10: Converged after 6563 steps.
# on 10: 2.542064301915858e-14
# on 10: 9.98171436616957e-14
# on 10: There are 1 electrons in the dot.
# on 11: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0022), 'half_donut_bottom': np.float64(0.0022), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 11: Converged after 5239 steps.
# on 11: 2.830552407624312e-14
# on 11: 9.98505012839157e-14
# on 11: There are 1 electrons in the dot.
# on 12: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0024000000000000002), 'half_donut_bottom': np.float64(0.0024000000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 12: Converged after 3828 steps.
# on 12: 1.2316848750784398e-13
# on 12: 9.960635624639557e-14
# on 12: There are 1 electrons in the dot.
# on 13: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0026000000000000003), 'half_donut_bottom': np.float64(0.0026000000000000003), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 13: Converged after 4010 steps.
# on 13: 6.413931197231461e-14
# on 13: 9.965318886751005e-14
# on 13: There are 1 electrons in the dot.
# on 14: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0028), 'half_donut_bottom': np.float64(0.0028), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 14: Converged after 4455 steps.
# on 14: 3.623696758724033e-14
# on 14: 9.999302619592698e-14
# on 14: There are 1 electrons in the dot.
# on 15: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.003), 'half_donut_bottom': np.float64(0.003), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 15: Converged after 4930 steps.
# on 15: 2.916088124312203e-14
# on 15: 9.9808953515218e-14
# on 15: There are 1 electrons in the dot.
# on 16: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0032), 'half_donut_bottom': np.float64(0.0032), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 16: Converged after 4630 steps.
# on 16: 3.101310056962321e-14
# on 16: 9.957096876785781e-14
# on 16: There are 1 electrons in the dot.
# on 17: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0034000000000000002), 'half_donut_bottom': np.float64(0.0034000000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 17: Converged after 6011 steps.
# on 17: 2.7866597931589963e-14
# on 17: 9.983686672428853e-14
# on 17: There are 1 electrons in the dot.
# on 18: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0036000000000000003), 'half_donut_bottom': np.float64(0.0036000000000000003), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 18: Converged after 6128 steps.
# on 18: 2.6706079758246898e-14
# on 18: 9.995421092808681e-14
# on 18: There are 1 electrons in the dot.
# on 19: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0038), 'half_donut_bottom': np.float64(0.0038), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 19: Converged after 5541 steps.
# on 19: 2.7280370833170536e-14
# on 19: 9.982592708013272e-14
# on 19: There are 1 electrons in the dot.
# on 20: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.004), 'half_donut_bottom': np.float64(0.004), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 20: Converged after 6425 steps.
# on 20: 2.5755441175097046e-14
# on 20: 9.970278824766865e-14
# on 20: There are 1 electrons in the dot.
# on 21: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.004200000000000001), 'half_donut_bottom': np.float64(0.004200000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 21: Converged after 4066 steps.
# on 21: 4.930953370856497e-14
# on 21: 9.985762258746256e-14
# on 21: There are 1 electrons in the dot.
# on 22: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0044), 'half_donut_bottom': np.float64(0.0044), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 22: Converged after 3528 steps.
# on 22: 2.1888130369795075e-14
# on 22: 9.984261062356835e-14
# on 22: There are 1 electrons in the dot.
# on 23: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0046), 'half_donut_bottom': np.float64(0.0046), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 23: Converged after 4108 steps.
# on 23: 4.343829127348291e-14
# on 23: 9.965224645469561e-14
# on 23: There are 1 electrons in the dot.
# on 24: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0048000000000000004), 'half_donut_bottom': np.float64(0.0048000000000000004), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 24: Converged after 5098 steps.
# on 24: 2.805352698676016e-14
# on 24: 9.978386036890717e-14
# on 24: There are 1 electrons in the dot.
# on 25: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.005), 'half_donut_bottom': np.float64(0.005), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 25: Converged after 3754 steps.
# on 25: 8.485800734638994e-14
# on 25: 9.994103389310281e-14
# on 25: There are 1 electrons in the dot.
# on 26: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.005200000000000001), 'half_donut_bottom': np.float64(0.005200000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 26: Converged after 4442 steps.
# on 26: 3.143968407800315e-14
# on 26: 9.987291328238805e-14
# on 26: There are 1 electrons in the dot.
# on 27: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0054), 'half_donut_bottom': np.float64(0.0054), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 27: Converged after 3736 steps.
# on 27: 1.0699493939695274e-13
# on 27: 9.975040189680318e-14
# on 27: There are 1 electrons in the dot.
# on 28: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0056), 'half_donut_bottom': np.float64(0.0056), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 28: Converged after 6661 steps.
# on 28: 2.4634834380018562e-14
# on 28: 9.988428167906349e-14
# on 28: There are 1 electrons in the dot.
# on 29: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0058000000000000005), 'half_donut_bottom': np.float64(0.0058000000000000005), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 29: Converged after 5054 steps.
# on 29: 2.6137123745018525e-14
# on 29: 9.990155686034896e-14
# on 29: There are 1 electrons in the dot.
# on 30: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.006), 'half_donut_bottom': np.float64(0.006), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 30: Converged after 4803 steps.
# on 30: 3.425609321186534e-14
# on 30: 9.96523372986946e-14
# on 30: There are 1 electrons in the dot.
# on 31: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.006200000000000001), 'half_donut_bottom': np.float64(0.006200000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 31: Converged after 4217 steps.
# on 31: 3.403742774460669e-14
# on 31: 9.997455879817708e-14
# on 31: There are 1 electrons in the dot.
# on 32: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0064), 'half_donut_bottom': np.float64(0.0064), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 32: Converged after 4198 steps.
# on 32: 3.52750685415271e-14
# on 32: 9.96054602964147e-14
# on 32: There are 1 electrons in the dot.
# on 33: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0066), 'half_donut_bottom': np.float64(0.0066), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 33: Converged after 4353 steps.
# on 33: 4.541378839748693e-14
# on 33: 9.936471395688429e-14
# on 33: There are 1 electrons in the dot.
# on 34: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0068000000000000005), 'half_donut_bottom': np.float64(0.0068000000000000005), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 34: Converged after 3981 steps.
# on 34: 3.845121006534565e-14
# on 34: 9.985135867489683e-14
# on 34: There are 1 electrons in the dot.
# on 35: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.007), 'half_donut_bottom': np.float64(0.007), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 35: Converged after 4973 steps.
# on 35: 3.1317277043144466e-14
# on 35: 9.97924738399547e-14
# on 35: There are 1 electrons in the dot.
# on 36: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.007200000000000001), 'half_donut_bottom': np.float64(0.007200000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 36: Converged after 4093 steps.
# on 36: 4.074708181717564e-14
# on 36: 9.979230353174272e-14
# on 36: There are 1 electrons in the dot.
# on 37: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0074), 'half_donut_bottom': np.float64(0.0074), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 37: Converged after 4524 steps.
# on 37: 3.535443991841205e-14
# on 37: 9.972816068272439e-14
# on 37: There are 1 electrons in the dot.
# on 38: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0076), 'half_donut_bottom': np.float64(0.0076), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 38: Converged after 5965 steps.
# on 38: 3.422806827325764e-14
# on 38: 9.99334852647138e-14
# on 38: There are 1 electrons in the dot.
# on 39: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0078000000000000005), 'half_donut_bottom': np.float64(0.0078000000000000005), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 39: Converged after 5633 steps.
# on 39: 3.1003642272030366e-14
# on 39: 9.971719760332176e-14
# on 39: There are 1 electrons in the dot.
# on 40: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.008), 'half_donut_bottom': np.float64(0.008), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 40: Converged after 8376 steps.
# on 40: 2.352793657950547e-14
# on 40: 9.982331464208904e-14
# on 40: There are 1 electrons in the dot.
# on 41: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0082), 'half_donut_bottom': np.float64(0.0082), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 41: Converged after 6896 steps.
# on 41: 2.670450696804471e-14
# on 41: 9.974053558721093e-14
# on 41: There are 1 electrons in the dot.
# on 42: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.008400000000000001), 'half_donut_bottom': np.float64(0.008400000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 42: Converged after 7422 steps.
# on 42: 2.4862202481692743e-14
# on 42: 9.982519369455822e-14
# on 42: There are 1 electrons in the dot.
# on 43: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0086), 'half_donut_bottom': np.float64(0.0086), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 43: Converged after 8187 steps.
# on 43: 2.2100718324157103e-14
# on 43: 9.994814051395018e-14
# on 43: There are 1 electrons in the dot.
# on 44: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0088), 'half_donut_bottom': np.float64(0.0088), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 44: Converged after 9812 steps.
# on 44: 3.139601310827396e-14
# on 44: 9.984863962204937e-14
# on 44: There are 1 electrons in the dot.
# on 45: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.009000000000000001), 'half_donut_bottom': np.float64(0.009000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 45: Converged after 8154 steps.
# on 45: 3.1725483366114574e-14
# on 45: 9.995324526390626e-14
# on 45: There are 1 electrons in the dot.
# on 46: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0092), 'half_donut_bottom': np.float64(0.0092), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 46: Converged after 11268 steps.
# on 46: 2.1377887560196872e-14
# on 46: 9.999818056938282e-14
# on 46: There are 1 electrons in the dot.
# on 47: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0094), 'half_donut_bottom': np.float64(0.0094), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 47: Converged after 12000 steps.
# on 47: 2.931098045090602e-14
# on 47: 9.997099237324392e-14
# on 47: There are 1 electrons in the dot.
# on 48: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.009600000000000001), 'half_donut_bottom': np.float64(0.009600000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 48: Converged after 11682 steps.
# on 48: 2.1546658650276383e-14
# on 48: 9.995133049001124e-14
# on 48: There are 1 electrons in the dot.
# on 49: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0098), 'half_donut_bottom': np.float64(0.0098), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 49: Converged after 21039 steps.
# on 49: 2.0678736906169003e-14
# on 49: 9.991122150269927e-14
# on 49: There are 1 electrons in the dot.
# on 50: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.01), 'half_donut_bottom': np.float64(0.01), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 50: Converged after 14400 steps.
# on 50: 2.1543859559089732e-14
# on 50: 9.992315772033855e-14
# on 50: There are 1 electrons in the dot.
# on 51: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0102), 'half_donut_bottom': np.float64(0.0102), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 51: Converged after 12614 steps.
# on 51: 2.2124344189301956e-14
# on 51: 9.994450341638261e-14
# on 51: There are 1 electrons in the dot.
# on 52: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.010400000000000001), 'half_donut_bottom': np.float64(0.010400000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 52: Converged after 13798 steps.
# on 52: 2.428717481879652e-14
# on 52: 9.989639992991072e-14
# on 52: There are 1 electrons in the dot.
# on 53: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0106), 'half_donut_bottom': np.float64(0.0106), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 53: Converged after 13768 steps.
# on 53: 2.1206025225964575e-14
# on 53: 9.9915028028974e-14
# on 53: There are 1 electrons in the dot.
# on 54: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0108), 'half_donut_bottom': np.float64(0.0108), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 54: Converged after 14362 steps.
# on 54: 2.1148429617624433e-14
# on 54: 9.993799177099304e-14
# on 54: There are 1 electrons in the dot.
# on 55: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.011000000000000001), 'half_donut_bottom': np.float64(0.011000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 55: Converged after 14116 steps.
# on 55: 2.0637096474295002e-14
# on 55: 9.987745680506421e-14
# on 55: There are 1 electrons in the dot.
# on 56: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0112), 'half_donut_bottom': np.float64(0.0112), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 56: Converged after 13095 steps.
# on 56: 2.4764850188928098e-14
# on 56: 9.98936736107403e-14
# on 56: There are 1 electrons in the dot.
# on 57: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0114), 'half_donut_bottom': np.float64(0.0114), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 57: Converged after 13478 steps.
# on 57: 2.5256893791848405e-14
# on 57: 9.995710771593114e-14
# on 57: There are 1 electrons in the dot.
# on 58: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.011600000000000001), 'half_donut_bottom': np.float64(0.011600000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 58: Converged after 14399 steps.
# on 58: 2.3493863631778594e-14
# on 58: 9.997029688790792e-14
# on 58: There are 1 electrons in the dot.
# on 59: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0118), 'half_donut_bottom': np.float64(0.0118), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 59: Converged after 17335 steps.
# on 59: 2.5550611581463074e-14
# on 59: 9.991663251461558e-14
# on 59: There are 1 electrons in the dot.
# on 60: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.012), 'half_donut_bottom': np.float64(0.012), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 60: Converged after 17602 steps.
# on 60: 2.0351537778539705e-14
# on 60: 9.997766153846399e-14
# on 60: There are 1 electrons in the dot.
# on 61: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0122), 'half_donut_bottom': np.float64(0.0122), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 61: Converged after 20576 steps.
# on 61: 2.618392746680107e-14
# on 61: 9.99200249747565e-14
# on 61: There are 1 electrons in the dot.
# on 62: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.012400000000000001), 'half_donut_bottom': np.float64(0.012400000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 62: Converged after 22739 steps.
# on 62: 2.0124357399769563e-14
# on 62: 9.994389644585408e-14
# on 62: There are 1 electrons in the dot.
# on 63: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0126), 'half_donut_bottom': np.float64(0.0126), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 63: Converged after 26301 steps.
# on 63: 1.8829555969990253e-14
# on 63: 9.997883913836525e-14
# on 63: There are 1 electrons in the dot.
# on 64: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0128), 'half_donut_bottom': np.float64(0.0128), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 64: Converged after 29460 steps.
# on 64: 1.8671714990232707e-14
# on 64: 9.998840974027173e-14
# on 64: There are 1 electrons in the dot.
# on 65: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.013000000000000001), 'half_donut_bottom': np.float64(0.013000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 65: Converged after 35649 steps.
# on 65: 1.8486948083484833e-14
# on 65: 9.997889685803631e-14
# on 65: There are 1 electrons in the dot.
# on 66: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0132), 'half_donut_bottom': np.float64(0.0132), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 66: Converged after 29479 steps.
# on 66: 1.878414915801967e-14
# on 66: 9.997380050717763e-14
# on 66: There are 1 electrons in the dot.
# on 67: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0134), 'half_donut_bottom': np.float64(0.0134), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 67: Converged after 52857 steps.
# on 67: 1.8236280541206185e-14
# on 67: 9.998610094535892e-14
# on 67: There are 1 electrons in the dot.
# on 68: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.013600000000000001), 'half_donut_bottom': np.float64(0.013600000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 68: Converged after 72768 steps.                                              ▃▁▃ 68/101 [67%] in 1:00 (~29s, 1.1/s
# on 68: 1.809750266312804e-14
# on 68: 9.999502650124557e-14
# on 68: There are 1 electrons in the dot.
# on 69: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.013800000000000002), 'half_donut_bottom': np.float64(0.013800000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 69: Converged after 116004 steps.                                             ▆▄▂ 69/101 [68%] in 1:02 (~28s, 1.1/s
# on 69: 1.7970000487643745e-14
# on 69: 9.999217089938986e-14
# on 69: There are 1 electrons in the dot.
# on 70: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.014), 'half_donut_bottom': np.float64(0.014), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 70: Converged after 273657 steps.
# on 70: 1.7857243461705252e-14
# on 70: 9.999619469264198e-14
# on 70: There are 1 electrons in the dot.
# on 71: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0142), 'half_donut_bottom': np.float64(0.0142), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 71: Converged after 165661 steps.
# on 71: 2.4168477255160382e-14
# on 71: 9.998347438866517e-14
# on 71: There are 1 electrons in the dot.
# on 72: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.014400000000000001), 'half_donut_bottom': np.float64(0.014400000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 72: Converged after 68897 steps.
# on 72: 2.4355228974648043e-14
# on 72: 9.999860339782173e-14
# on 72: There are 1 electrons in the dot.
# on 73: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0146), 'half_donut_bottom': np.float64(0.0146), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 73: Converged after 66268 steps.
# on 73: 2.4176763353717082e-14
# on 73: 9.998066691219163e-14
# on 73: There are 1 electrons in the dot.
# on 74: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0148), 'half_donut_bottom': np.float64(0.0148), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 74: Converged after 65672 steps.
# on 74: 2.4314898120457263e-14
# on 74: 9.998040347014568e-14
# on 74: There are 1 electrons in the dot.
# on 75: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.015000000000000001), 'half_donut_bottom': np.float64(0.015000000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 75: Converged after 61267 steps.
# on 75: 2.4778874656579398e-14
# on 75: 9.99627617834231e-14
# on 75: There are 1 electrons in the dot.
# on 76: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0152), 'half_donut_bottom': np.float64(0.0152), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 76: Converged after 72127 steps.
# on 76: 1.5737411374061594e-14
# on 76: 9.998850418468929e-14
# on 76: There are 1 electrons in the dot.
# on 77: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0154), 'half_donut_bottom': np.float64(0.0154), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 77: Converged after 63997 steps.
# on 77: 2.4923085084465454e-14
# on 77: 9.997081748362723e-14
# on 77: There are 1 electrons in the dot.
# on 78: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.015600000000000001), 'half_donut_bottom': np.float64(0.015600000000000001), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 78: Converged after 63113 steps.
# on 78: 2.4919313781983086e-14
# on 78: 9.998232893075046e-14
# on 78: There are 1 electrons in the dot.
# on 79: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0158), 'half_donut_bottom': np.float64(0.0158), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 79: Converged after 63153 steps.
# on 79: 2.5024387570476097e-14
# on 79: 9.998576899761247e-14
# on 79: There are 1 electrons in the dot.
# on 80: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.016), 'half_donut_bottom': np.float64(0.016), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 80: Converged after 62338 steps.
# on 80: 2.5126385398813156e-14
# on 80: 9.998304761893449e-14
# on 80: There are 1 electrons in the dot.
# on 81: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0162), 'half_donut_bottom': np.float64(0.0162), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 81: Converged after 60862 steps.
# on 81: 2.4702462297909733e-14
# on 81: 9.9972069733667e-14
# on 81: There are 1 electrons in the dot.
# on 82: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0164), 'half_donut_bottom': np.float64(0.0164), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 82: Converged after 59963 steps.
# on 82: 2.4842217028995475e-14
# on 82: 9.997372529824132e-14
# on 82: There are 1 electrons in the dot.
# on 83: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0166), 'half_donut_bottom': np.float64(0.0166), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 83: Converged after 48963 steps.
# on 83: 2.7217678441791293e-14
# on 83: 9.997079075674264e-14
# on 83: There are 1 electrons in the dot.
# on 84: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.016800000000000002), 'half_donut_bottom': np.float64(0.016800000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 84: Converged after 45992 steps.
# on 84: 2.672226331350675e-14
# on 84: 9.998073835504328e-14
# on 84: There are 1 electrons in the dot.
# on 85: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.017), 'half_donut_bottom': np.float64(0.017), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 85: Converged after 59899 steps.
# on 85: 2.7422508708241367e-14
# on 85: 9.996415428759065e-14
# on 85: There are 1 electrons in the dot.
# on 86: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0172), 'half_donut_bottom': np.float64(0.0172), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 86: Converged after 47842 steps.
# on 86: 2.727739120580975e-14
# on 86: 9.997913963388781e-14
# on 86: There are 1 electrons in the dot.
# on 87: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.017400000000000002), 'half_donut_bottom': np.float64(0.017400000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 87: Converged after 46587 steps.
# on 87: 2.747375806685963e-14
# on 87: 9.996359295882939e-14
# on 87: There are 1 electrons in the dot.
# on 88: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0176), 'half_donut_bottom': np.float64(0.0176), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 88: Converged after 57291 steps.
# on 88: 1.526990593458353e-14
# on 88: 9.998164163249611e-14
# on 88: There are 1 electrons in the dot.
# on 89: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0178), 'half_donut_bottom': np.float64(0.0178), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 89: Converged after 44584 steps.
# on 89: 1.49319837694036e-14
# on 89: 9.999918570979814e-14
# on 89: There are 1 electrons in the dot.
# on 90: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.018000000000000002), 'half_donut_bottom': np.float64(0.018000000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 90: Converged after 43749 steps.
# on 90: 1.5384202254451112e-14
# on 90: 9.997331607003444e-14
# on 90: There are 1 electrons in the dot.
# on 91: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0182), 'half_donut_bottom': np.float64(0.0182), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 91: Converged after 42810 steps.
# on 91: 1.5168263360990462e-14
# on 91: 9.998653327514262e-14
# on 91: There are 1 electrons in the dot.
# on 92: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0184), 'half_donut_bottom': np.float64(0.0184), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 92: Converged after 41820 steps.
# on 92: 1.5361350844315293e-14
# on 92: 9.999937916616019e-14
# on 92: There are 1 electrons in the dot.
# on 93: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.018600000000000002), 'half_donut_bottom': np.float64(0.018600000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 93: Converged after 40665 steps.
# on 93: 1.4876988529977098e-14
# on 93: 9.998487437989922e-14
# on 93: There are 1 electrons in the dot.
# on 94: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0188), 'half_donut_bottom': np.float64(0.0188), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 94: Converged after 52013 steps.
# on 94: 2.1797794967928332e-14
# on 94: 9.9987488511033e-14
# on 94: There are 1 electrons in the dot.
# on 95: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.019), 'half_donut_bottom': np.float64(0.019), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 95: Converged after 45033 steps.
# on 95: 1.4950236207163517e-14
# on 95: 9.997123839866618e-14
# on 95: There are 1 electrons in the dot.
# on 96: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.019200000000000002), 'half_donut_bottom': np.float64(0.019200000000000002), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 96: Converged after 44727 steps.
# on 96: 1.4894067047868032e-14
# on 96: 9.99900535703091e-14
# on 96: There are 1 electrons in the dot.
# on 97: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0194), 'half_donut_bottom': np.float64(0.0194), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 97: Converged after 44398 steps.
# on 97: 1.4981018908451382e-14
# on 97: 9.998368000196934e-14
# on 97: There are 1 electrons in the dot.
# on 98: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0196), 'half_donut_bottom': np.float64(0.0196), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 98: Converged after 44059 steps.
# on 98: 1.479057097542559e-14
# on 98: 9.9972069733667e-14
# on 98: There are 1 electrons in the dot.
# on 99: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.0198), 'half_donut_bottom': np.float64(0.0198), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 99: Converged after 43715 steps.
# on 99: 1.4767322640714007e-14
# on 99: 9.997639693892778e-14
# on 99: There are 1 electrons in the dot.
# on 100: Unloading 1 electrons with voltages: {'half_donut_top': np.float64(0.02), 'half_donut_bottom': np.float64(0.02), 'gate_top': -0.0, 'gate_bottom': 0.0, 'reservoir': 0.0, 'center': 0.01, 'guard': 0.0}
# on 100: Converged after 43342 steps.
# on 100: 1.4767322640714007e-14
# on 100: 9.998880301509416e-14
# on 100: There are 1 electrons in the dot.
# |████████████████████████████████████████| 101/101 [100%] in 3:35.2 (0.47/s)
# (0.0, 0.02)

# %%
fig, ax = plt.subplots(figsize=(7, 4.))

anim = f.animate_voltage_sweep(fig, ax,  list_of_voltages=list_of_voltages, list_of_electron_positions=electron_configurations,
                            dxdy=(3.8, 4), frame_interval_ms=100 )
f.show_animation(anim)
# Out:
# <video width="700" height="400" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
plt.plot(sweep_voltages, eigenfrequencies[:, 0])
plt.ylabel("Resonator frequency (Hz)")
plt.xlim(np.min(sweep_voltages), np.max(sweep_voltages))
# Out:
# (0.0, 0.02)

# %% [markdown]
# ### Voltage sweep 2

# %%
sweep_voltages = np.linspace(0.0012, 0.002, 101)
eigenfrequencies = np.zeros((len(sweep_voltages), 3))
plot = True

convergence_method='L-BFGS-B' # 'L-BFGS-B' or 'Physical gradient descent'

sweep_electrode = "half_donut_top"
vi = voltages[sweep_electrode]

with alive_progress.alive_bar(len(sweep_voltages), force_tty=True) as bar:
    for k, center in enumerate(sweep_voltages):

        voltages[sweep_electrode] = center

        N = 50

        f = FullModel(trap.dot, voltages, **options)
        f.remove_unbound_electrons = False
        f.trap_annealing_steps = [0.5] * 25

        f.set_rf_interpolator(rf_electrode_labels=['guard'])


        if k == 0:
            initial_condition = f.generate_initial_condition(N)
        else:
            initial_condition = equilibrium_positions

        if convergence_method == 'L-BFGS-B':

            init_x, init_y = r2xy(initial_condition)
            res = f.get_electron_positions(n_electrons=N, electron_initial_positions=initial_condition, verbose=False, gradient_tolerance=1e-9, ftol=1e-300)
            equilibrium_positions= res['x']
            electron_configurations.append(equilibrium_positions)
            final_x, final_y = r2xy(equilibrium_positions)
            if res['status'] != 0:
                print(f"Error at k={k}, status={res['status']}")
                print(f"Error message: {res['message']}")
                continue

        
        elif convergence_method == 'Physical gradient descent':
            n_timesteps = 6000
            dt = 1e-13 
            gamma = -0.01 * me / dt # This is the damping parameter. 
            r = np.zeros((2 * N, n_timesteps+2))

            r[:, 0] = initial_condition
            r[:, 1] = initial_condition

            for j in range(2, n_timesteps+2):
                prefactor = 1 / (me / dt ** 2 - gamma / dt)
                F = - qe * f.grad_total(r[:, j-1])
                r[:, j] = prefactor * (F - r[:, j-1] * (-2 * me / dt ** 2 + gamma / dt) - r[:, j-2] * me / dt ** 2)
                
            equilibrium_positions = r[:, -1]
            electron_configurations.append(equilibrium_positions)
            final_x, final_y = r2xy(equilibrium_positions)

    


       

        # if plot and not(k%10):
        #     f.plot_potential_energy(coor=[0, 0], dxdy=(3, 3))
        #     f.plot_electron_positions(res)

        # added: resonaotor_dict
    

        K, M = f.setup_eom(equilibrium_positions, resonator_dict=resonator_dict)
        eigenfrequencies[k, :], evecs = f.solve_eom(K, M, sort_by_cavity_participation=True)

        bar()




plt.figure()
plt.plot(sweep_voltages, eigenfrequencies / 1e9)
plt.xlabel(" Voltages (V)")
plt.ylabel("Frequency (GHz)")
plt.xlim(np.min(sweep_voltages), np.max(sweep_voltages))
# Out:
# |████████████████████████████████████████| 101/101 [100%] in 12.1s (8.35/s)
# (0.0012, 0.002)

# %%
N = 2

f = FullModel(trap.dot, voltages, **options)
f.remove_unbound_electrons = False
f.trap_annealing_steps = [4] * 25

f.set_rf_interpolator(rf_electrode_labels=['guard'])

initial_condition = f.generate_initial_condition(N)
init_x, init_y = r2xy(initial_condition)

res = f.get_electron_positions(n_electrons=N, electron_initial_positions=None, verbose=False)

final_x, final_y = r2xy(res['x'])

f.plot_potential_energy(coor=[0, 0], dxdy=(4, 4))
f.plot_electron_positions(res)


K, M = f.setup_eom(res['x'], resonator_dict=resonator_dict)
eigenfrequencies, evecs = f.solve_eom(K, M, sort_by_cavity_participation=True)
f.plot_eigenvector(res['x'], evecs[:, 2], color='white')
f.plot_eigenvector(res['x'], evecs[:, 1], color='gray')

print(eigenfrequencies)
# Out:
# [7.99999977e+08 4.67440870e+09 1.08496049e+10 6.69986487e+09
#  9.95985279e+09]

# %%
f.plot_convergence()

# %%
# difference between the mode most coupled to the resonator and the resonator frequency
f.get_cavity_frequency_shift(K, M)
# Out:
# np.float64(-23.18082332611084)

# %% [markdown]
# ## Unloading

# %% [markdown]
# ### Options and widgets

# %%
from quantum_electron.utils import crop_potential



left_boundary = -5 # microns

voltages = {
    'half_donut_top':0.3,
    'half_donut_bottom':0.3,
    'gate_top':-0.03,
    'gate_bottom':-0.03,
    'reservoir':0.5,
    'center':0.0,
    'guard':-0.000,
}

for electrode in voltages.keys():
    new_x, new_y, new_U = crop_potential(x=trap.dot['xlist'], y=trap.dot['ylist'], U=trap.dot[electrode], 
                                         xrange=(left_boundary, 2), yrange=(-4, 4))
    
    trap.dot[electrode] = new_U

trap.dot['xlist'] = new_x 
trap.dot['ylist'] = new_y
 
x_min= np.min(trap.dot['xlist'])*1e-6
x_max= np.max(trap.dot['xlist'])*1e-6
y_min= np.min(trap.dot['ylist'])*1e-6
y_max= np.max(trap.dot['ylist'])*1e-6
print(f"Potential grid: x_min={x_min:.2e}, x_max={x_max:.2e}, y_min={y_min:.2e}, y_max={y_max:.2e}")




options = { "include_screening" : False, # Include screening of electron-electron interactions due to thin film.
           "screening_length" : np.inf, # Typically helium thickness.
           "potential_smoothing" : 1e-5, # Numerical smoothing of the splines (gets rid of some noise, can introduce artifacts)
           "remove_unbound_electrons" : False, # Removes electrons if they shot outside the solution box.
           "remove_bounds" : None, # Sets which electrons should be removed if above is True.
           "trap_annealing_steps" : [0.1] * 10, # List of annealing temperatures, length determines the number of steps
           "max_x_displacement" : 0.1e-6, # Maximum x-displacement of solved electron positions during annealing.
           "max_y_displacement" : 0.1e-6} # Maximum y-displacement of solved electron positions during annealing.



fig, ax = plt.subplots()
fm = FullModel(trap.dot, voltages, **options)
fm.plot_potential_energy(ax=ax, coor=[0,0], dxdy=(10, 8))
ax.set_xlim(-5, 2)
# Out:
# Potential grid: x_min=-5.00e-06, x_max=1.96e-06, y_min=-4.00e-06, y_max=3.96e-06
# (-5.0, 2.0)

# %%
Vrms = 140e-9
f0 = 0.800e9

Z = 2 / 1.055e-34 * (Vrms / (2 * np.pi * f0)) ** 2

resonator_dict = {"f0" : f0, # Resonance frequency for the resonator (only used for solving motional frequencies)
           "Z0" : Z }# Resonator impedance (only used for solving motional frequencies)

# %% [markdown]
# ### Unloading the dot

# %%
# cavity_freqs_list = []
# electron_modef_list=[]
# voltages_list = []


# for f0 in [0.120945e9, 0.400e9, 0.600e9, 0.800e9]:


voltages = {
    'half_donut_top':0.05,
    'half_donut_bottom':0.05,
    'gate_top':-0.03,
    'gate_bottom':-0.03,
    'reservoir':0.05,
    'center':0.0,
    'guard':0.0,
}

random.seed()

use_previous_initial_state = True
unload_voltages = np.linspace(-0.03, 0.03, 200) # for the gates
# unload_voltages_forward = np.linspace(0.007, 0.0005, 100) # for the reservoir
# unload_voltages_backward = unload_voltages_forward[::-1][1:]
# unload_voltages=np.concatenate((unload_voltages_forward, unload_voltages_backward))

# Initial number of electrons to start with
N_init = 5

temperature = 1.2 # Only important for calculation of the Gamma = Ec / Ek

# Keep track of some variables
energies = np.zeros(len(unload_voltages))
num_electrons = []
cavity_freqs=[]
electron_configurations = []
list_of_voltages = []
num_electrons_chgd_disk = np.zeros(len(unload_voltages))
num_electrons_par_cap = np.zeros(len(unload_voltages))
densities = np.zeros(len(unload_voltages))
gamma_param = np.zeros(len(unload_voltages))
disc_capacitances = np.zeros(len(unload_voltages))
electron_modef = []
trap_depth = np.zeros(len(unload_voltages))  
# Choose the convergence method for the calculation of the electron positions at equilibrium.
convergence_method = 'Physical gradient descent' # 'L-BFGS-B' or 'Physical gradient descent'



# Dimensionless rescaling
# Base units (SI → dimensionless)
L0 = 1e-6                      # 1 μm in meters
E0 = qe                        # 1 eV in joules
M0 = me                        # electron mass in kg
Q0 = qe                        # elementary charge in C
T0 = L0 * np.sqrt(M0/E0)      # derived time unit

# Convert physical timestep into dimensionless dt
dt_phys = 1e-13                # your original dt in seconds
dt = np.float64(dt_phys / T0)  # dimensionless

# redefine usual Verlet coefficients
gamma    = np.float64(-0.01) / dt
prefactor= np.float64(1.0) / (1.0/dt**2 - gamma/dt)
A        = np.float64(2.0/dt**2 - gamma/dt)
B        = np.float64(1.0/dt**2)

max_timesteps = 4000000 # Maximum number of timesteps for the convergence method

with alive_progress.alive_bar(len(unload_voltages), force_tty=True) as bar:
    for k, unload in enumerate(unload_voltages):

        # Here you can change how to unload the electrons (which electrodes to sweep)
        # voltages['center'] = unload
        # voltages['half_donut_top'] = unload
        # voltages['half_donut_bottom'] = unload
    
        voltages['gate_top'] = unload
        voltages['gate_bottom'] = unload
        # voltages['reservoir']=unload
        
        
        
        f = FullModel(trap.dot, voltages, **options)

        f.set_rf_interpolator(rf_electrode_labels=['guard'])
        
        if k == 0: 
            electron_initial_positions = f.generate_initial_condition(N_init, center=(0, 0), radius=0.1e-6)
            N = N_init
        elif use_previous_initial_state: 
            electron_initial_positions = equilibrium_positions
            N = len(electron_initial_positions) // 2
        else:
            electron_initial_positions = None
            N = N_init
        
        
        if N > 0:
            print(f'Unloading {N} electrons with voltages: {voltages}')
            max_force=[]
            if convergence_method == 'L-BFGS-B':
                res = f.get_electron_positions(n_electrons=N, 
                                            electron_initial_positions=electron_initial_positions, 
                                            verbose=False, 
                                            suppress_warnings=False)
                equilibrium_positions = res['x']

    

            if convergence_method == 'Physical gradient descent':
                # Convert the *physical* positions into primed coords:
                r_old = (electron_initial_positions / L0).astype(np.float64)
                r_cur = r_old.copy()
                j = 2

                while True:
                    # compute physical gradient at r_phys = r_cur*L0
                    grad_phys = f.grad_total(r_cur * L0)          # in V/m
                    F = -(qe * grad_phys) * (L0/E0)     # dimensionless
                    max_force.append(np.max(np.abs(F)))
                    

                    # damped Verlet integration: dimensionless
                    r_next = prefactor * (F + r_cur * A - r_old * B)

                    # if j% 1000 == 0:
                    #     print('1: '+str(np.average(np.abs(r_cur*A-r_old*B))))
                    #     print('2: '+str(np.average(np.abs(F))))

                    # 4) Remove electrons out of domain in primed coords
                    x_next = r_next[::2];  y_next = r_next[1::2]
                    inside = np.logical_and.reduce((
                        x_next*L0 >= x_min, x_next*L0 <= x_max,
                        y_next*L0 >= y_min, y_next*L0 <= y_max
                    ))


                    r_next_filtered    = np.empty((2*np.sum(inside)), dtype=np.float64)
                    r_current_filtered = np.empty((2*np.sum(inside)), dtype=np.float64)

                    r_next_filtered[::2]    = x_next[inside]
                    r_next_filtered[1::2]   = y_next[inside]
                    r_current_filtered[::2] = r_cur[::2][inside]
                    r_current_filtered[1::2]= r_cur[1::2][inside]

                    # rotate for next pass
                    r_old, r_cur = r_current_filtered, r_next_filtered
                    j += 1

                    # 5) Check convergence in dimensionless force
                    if len(r_cur)==0:
                        print(f'During the convergence, no electrons left after {j} steps.')
                        break
                    
                    if np.max(np.abs(F)) < 1e-12:
                        print(f'Converged after {j} steps.')
                        r_cur = r_next_filtered
                        break

                    if j >= max_timesteps:
                        print(f'Not converged after {max_timesteps} steps.')
                        break

                # Convert *back* to physical coordinates (meters)
                equilibrium_positions = (r_cur * L0)
                
            if len(r_cur)>0:
                print(f'The maximum distance between between two iterations is {np.max(np.abs(r_cur - r_old) * 1e12):.2f} pm.')
                print(f'Max force: {max_force[-1]}')
            final_x, final_y = r2xy(equilibrium_positions)
            
            
            

        if N==0:
            print(f'During the voltage sweep, no electrons left after {k} steps.')
            break
        
        K, M = f.setup_eom(equilibrium_positions, resonator_dict)
        eigenfrequencies, evecs = f.solve_eom(K, M, sort_by_cavity_participation=True)
        
        if len(equilibrium_positions) > 0:
            electron_configurations.append(equilibrium_positions)
            num_electrons.append(f.count_electrons_in_dot(equilibrium_positions, trap_bounds_x=(-1.5*1e-6,1.5*1e-6), trap_bounds_y=(-1.5*1e-6,1.5*1e-6))) #if trap_bounds_x,y is not specified, the default value is (-1e-6, 1e-6) for both x and y.
            electron_modef.append(eigenfrequencies[1])
            cavity_freqs.append(eigenfrequencies[0])
            list_of_voltages.append(voltages.copy())
            print('The cavity frequency is: ', eigenfrequencies[0])


        
        bar()
                
    # cavity_freqs_list.append(cavity_freqs)
    # electron_modef_list.append(electron_modef)
# Out:
# on 0: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.03), 'gate_bottom': np.float64(-0.03), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 0: Converged after 19970 steps.
# on 0: The maximum distance between between two iterations is 0.20 pm.
# on 0: Max force: 9.99354597297497e-13
# on 0: The cavity frequency is:  799999943.5772486
# on 1: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.029698492462311557), 'gate_bottom': np.float64(-0.029698492462311557), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 1: Converged after 15358 steps.
# on 1: The maximum distance between between two iterations is 0.20 pm.
# on 1: Max force: 9.98994437395595e-13
# on 1: The cavity frequency is:  799999944.0389407
# on 2: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.029396984924623115), 'gate_bottom': np.float64(-0.029396984924623115), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 2: Converged after 15328 steps.
# on 2: The maximum distance between between two iterations is 0.20 pm.
# on 2: Max force: 9.990135367843323e-13
# on 2: The cavity frequency is:  799999944.0172979
# on 3: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.029095477386934673), 'gate_bottom': np.float64(-0.029095477386934673), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 3: Converged after 15321 steps.
# on 3: The maximum distance between between two iterations is 0.20 pm.
# on 3: Max force: 9.997806955652775e-13
# on 3: The cavity frequency is:  799999943.9953437
# on 4: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02879396984924623), 'gate_bottom': np.float64(-0.02879396984924623), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 4: Converged after 15122 steps.
# on 4: The maximum distance between between two iterations is 0.20 pm.
# on 4: Max force: 9.9927410701639e-13
# on 4: The cavity frequency is:  799999944.1803434
# on 5: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02849246231155779), 'gate_bottom': np.float64(-0.02849246231155779), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 5: Converged after 15180 steps.
# on 5: The maximum distance between between two iterations is 0.20 pm.
# on 5: Max force: 9.99102667265106e-13
# on 5: The cavity frequency is:  799999944.1519235
# on 6: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.028190954773869344), 'gate_bottom': np.float64(-0.028190954773869344), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 6: Converged after 15175 steps.
# on 6: The maximum distance between between two iterations is 0.20 pm.
# on 6: Max force: 9.98998984869104e-13
# on 6: The cavity frequency is:  799999944.1231216
# on 7: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.027889447236180902), 'gate_bottom': np.float64(-0.027889447236180902), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 7: Converged after 15169 steps.
# on 7: The maximum distance between between two iterations is 0.20 pm.
# on 7: Max force: 9.989475984184536e-13
# on 7: The cavity frequency is:  799999944.0941496
# on 8: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02758793969849246), 'gate_bottom': np.float64(-0.02758793969849246), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 8: Converged after 15536 steps.
# on 8: The maximum distance between between two iterations is 0.20 pm.
# on 8: Max force: 9.992609193432144e-13
# on 8: The cavity frequency is:  799999944.2768751
# on 9: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02728643216080402), 'gate_bottom': np.float64(-0.02728643216080402), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 9: Converged after 15034 steps.
# on 9: The maximum distance between between two iterations is 0.20 pm.
# on 9: Max force: 9.998298082791735e-13
# on 9: The cavity frequency is:  799999944.2590878
# on 10: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.026984924623115577), 'gate_bottom': np.float64(-0.026984924623115577), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 10: Converged after 15022 steps.
# on 10: The maximum distance between between two iterations is 0.20 pm.
# on 10: Max force: 9.994373613153583e-13
# on 10: The cavity frequency is:  799999944.2407484
# on 11: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.026683417085427135), 'gate_bottom': np.float64(-0.026683417085427135), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 11: Converged after 15013 steps.
# on 11: The maximum distance between between two iterations is 0.20 pm.
# on 11: Max force: 9.992818377213552e-13
# on 11: The cavity frequency is:  799999944.2218611
# on 12: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.026381909547738693), 'gate_bottom': np.float64(-0.026381909547738693), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 12: Converged after 15004 steps.
# on 12: The maximum distance between between two iterations is 0.20 pm.
# on 12: Max force: 9.99891199171543e-13
# on 12: The cavity frequency is:  799999944.2023597
# on 13: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02608040201005025), 'gate_bottom': np.float64(-0.02608040201005025), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 13: Converged after 15013 steps.
# on 13: The maximum distance between between two iterations is 0.20 pm.
# on 13: Max force: 9.994928404921666e-13
# on 13: The cavity frequency is:  799999943.789224
# on 14: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02577889447236181), 'gate_bottom': np.float64(-0.02577889447236181), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 14: Converged after 18174 steps.
# on 14: The maximum distance between between two iterations is 0.20 pm.
# on 14: Max force: 9.995460459322202e-13
# on 14: The cavity frequency is:  799999941.7625946
# on 15: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.025477386934673364), 'gate_bottom': np.float64(-0.025477386934673364), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 15: Converged after 16891 steps.
# on 15: The maximum distance between between two iterations is 0.20 pm.
# on 15: Max force: 9.995251275540796e-13
# on 15: The cavity frequency is:  799999941.7660578
# on 16: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.025175879396984922), 'gate_bottom': np.float64(-0.025175879396984922), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 16: Converged after 16845 steps.
# on 16: The maximum distance between between two iterations is 0.20 pm.
# on 16: Max force: 9.990926628233865e-13
# on 16: The cavity frequency is:  799999941.7692397
# on 17: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02487437185929648), 'gate_bottom': np.float64(-0.02487437185929648), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 17: Converged after 16800 steps.
# on 17: The maximum distance between between two iterations is 0.20 pm.
# on 17: Max force: 9.992863851948641e-13
# on 17: The cavity frequency is:  799999941.7752421
# on 18: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02457286432160804), 'gate_bottom': np.float64(-0.02457286432160804), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 18: Converged after 15654 steps.
# on 18: The maximum distance between between two iterations is 0.20 pm.
# on 18: Max force: 9.999621397582814e-13
# on 18: The cavity frequency is:  799999943.0422224
# on 19: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.024271356783919597), 'gate_bottom': np.float64(-0.024271356783919597), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 19: Converged after 15504 steps.
# on 19: The maximum distance between between two iterations is 0.20 pm.
# on 19: Max force: 9.994969332183245e-13
# on 19: The cavity frequency is:  799999943.0025448
# on 20: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.023969849246231155), 'gate_bottom': np.float64(-0.023969849246231155), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 20: Converged after 15514 steps.
# on 20: The maximum distance between between two iterations is 0.20 pm.
# on 20: Max force: 9.999503163271583e-13
# on 20: The cavity frequency is:  799999942.9627863
# on 21: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.023668341708542713), 'gate_bottom': np.float64(-0.023668341708542713), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 21: Converged after 16119 steps.
# on 21: The maximum distance between between two iterations is 0.20 pm.
# on 21: Max force: 9.990285434469114e-13
# on 21: The cavity frequency is:  799999943.2487876
# on 22: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02336683417085427), 'gate_bottom': np.float64(-0.02336683417085427), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 22: Converged after 15457 steps.
# on 22: The maximum distance between between two iterations is 0.20 pm.
# on 22: Max force: 9.99302756099496e-13
# on 22: The cavity frequency is:  799999943.2432349
# on 23: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02306532663316583), 'gate_bottom': np.float64(-0.02306532663316583), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 23: Converged after 15462 steps.
# on 23: The maximum distance between between two iterations is 0.20 pm.
# on 23: Max force: 9.997015695262233e-13
# on 23: The cavity frequency is:  799999943.2371424
# on 24: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.022763819095477388), 'gate_bottom': np.float64(-0.022763819095477388), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 24: Converged after 15466 steps.
# on 24: The maximum distance between between two iterations is 0.20 pm.
# on 24: Max force: 9.998366294894367e-13
# on 24: The cavity frequency is:  799999943.2304899
# on 25: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.022462311557788946), 'gate_bottom': np.float64(-0.022462311557788946), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 25: Converged after 15197 steps.
# on 25: The maximum distance between between two iterations is 0.20 pm.
# on 25: Max force: 9.99574695015326e-13
# on 25: The cavity frequency is:  799999943.6263735
# on 26: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.022160804020100504), 'gate_bottom': np.float64(-0.022160804020100504), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 26: Converged after 16561 steps.
# on 26: The maximum distance between between two iterations is 0.20 pm.
# on 26: Max force: 9.99238636723021e-13
# on 26: The cavity frequency is:  799999944.042282
# on 27: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.021859296482412062), 'gate_bottom': np.float64(-0.021859296482412062), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 27: Converged after 15705 steps.
# on 27: The maximum distance between between two iterations is 0.20 pm.
# on 27: Max force: 9.994055290007965e-13
# on 27: The cavity frequency is:  799999944.0148898
# on 28: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02155778894472362), 'gate_bottom': np.float64(-0.02155778894472362), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 28: Converged after 19641 steps.
# on 28: The maximum distance between between two iterations is 0.19 pm.
# on 28: Max force: 9.990894795919302e-13
# on 28: The cavity frequency is:  799999940.8807417
# on 29: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02125628140703518), 'gate_bottom': np.float64(-0.02125628140703518), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 29: Converged after 17797 steps.
# on 29: The maximum distance between between two iterations is 0.19 pm.
# on 29: Max force: 9.990885700972283e-13
# on 29: The cavity frequency is:  799999940.8249092
# on 30: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.020954773869346733), 'gate_bottom': np.float64(-0.020954773869346733), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 30: Converged after 17841 steps.
# on 30: The maximum distance between between two iterations is 0.19 pm.
# on 30: Max force: 9.999080248235258e-13
# on 30: The cavity frequency is:  799999940.7664139
# on 31: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02065326633165829), 'gate_bottom': np.float64(-0.02065326633165829), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 31: Converged after 17890 steps.
# on 31: The maximum distance between between two iterations is 0.19 pm.
# on 31: Max force: 9.995155778597108e-13
# on 31: The cavity frequency is:  799999940.7052449
# on 32: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.02035175879396985), 'gate_bottom': np.float64(-0.02035175879396985), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 32: Converged after 17942 steps.
# on 32: The maximum distance between between two iterations is 0.19 pm.
# on 32: Max force: 9.99542862700764e-13
# on 32: The cavity frequency is:  799999940.6412523
# on 33: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.020050251256281407), 'gate_bottom': np.float64(-0.020050251256281407), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 33: Converged after 17988 steps.
# on 33: The maximum distance between between two iterations is 0.20 pm.
# on 33: Max force: 9.999371286539825e-13
# on 33: The cavity frequency is:  799999940.5811716
# on 34: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.019748743718592966), 'gate_bottom': np.float64(-0.019748743718592966), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 34: Converged after 17923 steps.
# on 34: The maximum distance between between two iterations is 0.20 pm.
# on 34: Max force: 9.992563718697057e-13
# on 34: The cavity frequency is:  799999940.603425
# on 35: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.01944723618090452), 'gate_bottom': np.float64(-0.01944723618090452), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 35: Converged after 17856 steps.
# on 35: The maximum distance between between two iterations is 0.20 pm.
# on 35: Max force: 9.992040759243537e-13
# on 35: The cavity frequency is:  799999940.6247754
# on 36: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.01914572864321608), 'gate_bottom': np.float64(-0.01914572864321608), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 36: Converged after 17791 steps.
# on 36: The maximum distance between between two iterations is 0.20 pm.
# on 36: Max force: 9.997997949540148e-13
# on 36: The cavity frequency is:  799999940.6453404
# on 37: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.018844221105527637), 'gate_bottom': np.float64(-0.018844221105527637), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 37: Converged after 17731 steps.
# on 37: The maximum distance between between two iterations is 0.20 pm.
# on 37: Max force: 9.999216672440525e-13
# on 37: The cavity frequency is:  799999940.6652246
# on 38: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.018542713567839195), 'gate_bottom': np.float64(-0.018542713567839195), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 38: Converged after 17676 steps.
# on 38: The maximum distance between between two iterations is 0.20 pm.
# on 38: Max force: 9.993564162869005e-13
# on 38: The cavity frequency is:  799999940.6843598
# on 39: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.018241206030150753), 'gate_bottom': np.float64(-0.018241206030150753), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 39: Converged after 17624 steps.
# on 39: The maximum distance between between two iterations is 0.20 pm.
# on 39: Max force: 9.996547305490822e-13
# on 39: The cavity frequency is:  799999940.7025956
# on 40: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.01793969849246231), 'gate_bottom': np.float64(-0.01793969849246231), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 40: Converged after 17576 steps.
# on 40: The maximum distance between between two iterations is 0.20 pm.
# on 40: Max force: 9.995014806918334e-13
# on 40: The cavity frequency is:  799999940.7198243
# on 41: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.01763819095477387), 'gate_bottom': np.float64(-0.01763819095477387), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 41: Converged after 18239 steps.
# on 41: The maximum distance between between two iterations is 0.19 pm.
# on 41: Max force: 9.992895684263202e-13
# on 41: The cavity frequency is:  799999942.4191653
# on 42: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.017336683417085427), 'gate_bottom': np.float64(-0.017336683417085427), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 42: Converged after 16630 steps.
# on 42: The maximum distance between between two iterations is 0.20 pm.
# on 42: Max force: 9.992086233978626e-13
# on 42: The cavity frequency is:  799999942.3315166
# on 43: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.017035175879396985), 'gate_bottom': np.float64(-0.017035175879396985), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 43: Converged after 16714 steps.
# on 43: The maximum distance between between two iterations is 0.20 pm.
# on 43: Max force: 9.99995791062247e-13
# on 43: The cavity frequency is:  799999942.2392749
# on 44: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.016733668341708544), 'gate_bottom': np.float64(-0.016733668341708544), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 44: Converged after 16803 steps.
# on 44: The maximum distance between between two iterations is 0.20 pm.
# on 44: Max force: 9.995055734179913e-13
# on 44: The cavity frequency is:  799999942.1424489
# on 45: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.0164321608040201), 'gate_bottom': np.float64(-0.0164321608040201), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 45: Converged after 16889 steps.
# on 45: The maximum distance between between two iterations is 0.20 pm.
# on 45: Max force: 9.996897460951005e-13
# on 45: The cavity frequency is:  799999942.042096
# on 46: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.01613065326633166), 'gate_bottom': np.float64(-0.01613065326633166), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 46: Converged after 16898 steps.
# on 46: The maximum distance between between two iterations is 0.20 pm.
# on 46: Max force: 9.998420864576473e-13
# on 46: The cavity frequency is:  799999942.0252424
# on 47: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.015829145728643218), 'gate_bottom': np.float64(-0.015829145728643218), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 47: Converged after 16899 steps.
# on 47: The maximum distance between between two iterations is 0.20 pm.
# on 47: Max force: 9.99959866021527e-13
# on 47: The cavity frequency is:  799999942.0033957
# on 48: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.015527638190954774), 'gate_bottom': np.float64(-0.015527638190954774), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 48: Converged after 16908 steps.
# on 48: The maximum distance between between two iterations is 0.20 pm.
# on 48: Max force: 9.990558282879646e-13
# on 48: The cavity frequency is:  799999941.976515
# on 49: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.015226130653266333), 'gate_bottom': np.float64(-0.015226130653266333), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 49: Converged after 16919 steps.
# on 49: The maximum distance between between two iterations is 0.20 pm.
# on 49: Max force: 9.99066287477035e-13
# on 49: The cavity frequency is:  799999941.9448644
# on 50: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.01492462311557789), 'gate_bottom': np.float64(-0.01492462311557789), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 50: Converged after 16935 steps.
# on 50: The maximum distance between between two iterations is 0.20 pm.
# on 50: Max force: 9.993541425501462e-13
# on 50: The cavity frequency is:  799999941.9081831
# on 51: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.014623115577889447), 'gate_bottom': np.float64(-0.014623115577889447), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 51: Converged after 16952 steps.
# on 51: The maximum distance between between two iterations is 0.20 pm.
# on 51: Max force: 9.991445040213875e-13
# on 51: The cavity frequency is:  799999941.8667568
# on 52: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.014321608040201005), 'gate_bottom': np.float64(-0.014321608040201005), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 52: Converged after 18255 steps.
# on 52: The maximum distance between between two iterations is 0.20 pm.
# on 52: Max force: 9.994610081776045e-13
# on 52: The cavity frequency is:  799999940.9810305
# on 53: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.014020100502512563), 'gate_bottom': np.float64(-0.014020100502512563), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 53: Converged after 16827 steps.
# on 53: The maximum distance between between two iterations is 0.20 pm.
# on 53: Max force: 9.997465895139611e-13
# on 53: The cavity frequency is:  799999940.9721316
# on 54: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.013718592964824122), 'gate_bottom': np.float64(-0.013718592964824122), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 54: Converged after 16815 steps.
# on 54: The maximum distance between between two iterations is 0.20 pm.
# on 54: Max force: 9.990276339522097e-13
# on 54: The cavity frequency is:  799999940.961665
# on 55: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.01341708542713568), 'gate_bottom': np.float64(-0.01341708542713568), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 55: Converged after 16806 steps.
# on 55: The maximum distance between between two iterations is 0.20 pm.
# on 55: Max force: 9.994851097872014e-13
# on 55: The cavity frequency is:  799999940.9496993
# on 56: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.013115577889447238), 'gate_bottom': np.float64(-0.013115577889447238), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 56: Converged after 16798 steps.
# on 56: The maximum distance between between two iterations is 0.20 pm.
# on 56: Max force: 9.99146323010791e-13
# on 56: The cavity frequency is:  799999940.9361396
# on 57: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.012814070351758796), 'gate_bottom': np.float64(-0.012814070351758796), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 57: Converged after 16791 steps.
# on 57: The maximum distance between between two iterations is 0.20 pm.
# on 57: Max force: 9.994009815272876e-13
# on 57: The cavity frequency is:  799999940.9207791
# on 58: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.012512562814070354), 'gate_bottom': np.float64(-0.012512562814070354), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 58: Converged after 16786 steps.
# on 58: The maximum distance between between two iterations is 0.20 pm.
# on 58: Max force: 9.997884262702429e-13
# on 58: The cavity frequency is:  799999940.9039352
# on 59: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.012211055276381909), 'gate_bottom': np.float64(-0.012211055276381909), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 59: Converged after 16780 steps.
# on 59: The maximum distance between between two iterations is 0.20 pm.
# on 59: Max force: 9.999880603572819e-13
# on 59: The cavity frequency is:  799999940.8856258
# on 60: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.011909547738693467), 'gate_bottom': np.float64(-0.011909547738693467), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 60: Converged after 16774 steps.
# on 60: The maximum distance between between two iterations is 0.20 pm.
# on 60: Max force: 9.99290477921022e-13
# on 60: The cavity frequency is:  799999940.8660271
# on 61: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.011608040201005025), 'gate_bottom': np.float64(-0.011608040201005025), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 61: Converged after 18119 steps.
# on 61: The maximum distance between between two iterations is 0.19 pm.
# on 61: Max force: 9.999530448112636e-13
# on 61: The cavity frequency is:  799999941.4711193
# on 62: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.011306532663316583), 'gate_bottom': np.float64(-0.011306532663316583), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 62: Converged after 17282 steps.
# on 62: The maximum distance between between two iterations is 0.20 pm.
# on 62: Max force: 9.992140803660732e-13
# on 62: The cavity frequency is:  799999941.3269451
# on 63: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.011005025125628141), 'gate_bottom': np.float64(-0.011005025125628141), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 63: Converged after 17464 steps.
# on 63: The maximum distance between between two iterations is 0.20 pm.
# on 63: Max force: 9.993418643716724e-13
# on 63: The cavity frequency is:  799999941.1019692
# on 64: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.0107035175879397), 'gate_bottom': np.float64(-0.0107035175879397), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 64: Converged after 17658 steps.
# on 64: The maximum distance between between two iterations is 0.20 pm.
# on 64: Max force: 9.995860636990984e-13
# on 64: The cavity frequency is:  799999940.8650134
# on 65: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.010402010050251258), 'gate_bottom': np.float64(-0.010402010050251258), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 65: Converged after 18421 steps.
# on 65: The maximum distance between between two iterations is 0.20 pm.
# on 65: Max force: 9.991654223995282e-13
# on 65: The cavity frequency is:  799999941.4608642
# on 66: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.010100502512562816), 'gate_bottom': np.float64(-0.010100502512562816), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 66: Converged after 17517 steps.
# on 66: The maximum distance between between two iterations is 0.20 pm.
# on 66: Max force: 9.992122613766696e-13
# on 66: The cavity frequency is:  799999941.2778327
# on 67: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.009798994974874374), 'gate_bottom': np.float64(-0.009798994974874374), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 67: Converged after 18455 steps.
# on 67: The maximum distance between between two iterations is 0.20 pm.
# on 67: Max force: 9.997738743550145e-13
# on 67: The cavity frequency is:  799999939.8493397
# on 68: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.009497487437185932), 'gate_bottom': np.float64(-0.009497487437185932), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 68: Converged after 18133 steps.
# on 68: The maximum distance between between two iterations is 0.20 pm.
# on 68: Max force: 9.994696483772713e-13
# on 68: The cavity frequency is:  799999940.5454886
# on 69: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.00919597989949749), 'gate_bottom': np.float64(-0.00919597989949749), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 69: Converged after 18457 steps.
# on 69: The maximum distance between between two iterations is 0.19 pm.
# on 69: Max force: 9.994150786951648e-13
# on 69: The cavity frequency is:  799999939.6824207
# on 70: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.008894472361809045), 'gate_bottom': np.float64(-0.008894472361809045), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 70: Converged after 19492 steps.
# on 70: The maximum distance between between two iterations is 0.20 pm.
# on 70: Max force: 9.995005711971315e-13
# on 70: The cavity frequency is:  799999940.7568973
# on 71: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.008592964824120603), 'gate_bottom': np.float64(-0.008592964824120603), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 71: Converged after 17604 steps.
# on 71: The maximum distance between between two iterations is 0.20 pm.
# on 71: Max force: 9.997966117225586e-13
# on 71: The cavity frequency is:  799999940.6858828
# on 72: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.008291457286432161), 'gate_bottom': np.float64(-0.008291457286432161), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 72: Converged after 17595 steps.
# on 72: The maximum distance between between two iterations is 0.20 pm.
# on 72: Max force: 9.994855645345524e-13
# on 72: The cavity frequency is:  799999940.6688248
# on 73: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.00798994974874372), 'gate_bottom': np.float64(-0.00798994974874372), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 73: Converged after 20667 steps.
# on 73: The maximum distance between between two iterations is 0.19 pm.
# on 73: Max force: 9.999289432016667e-13
# on 73: The cavity frequency is:  799999939.0104738
# on 74: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.007688442211055278), 'gate_bottom': np.float64(-0.007688442211055278), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 74: Converged after 19285 steps.
# on 74: The maximum distance between between two iterations is 0.20 pm.
# on 74: Max force: 9.993182175094262e-13
# on 74: The cavity frequency is:  799999938.6477301
# on 75: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.007386934673366836), 'gate_bottom': np.float64(-0.007386934673366836), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 75: Converged after 20138 steps.
# on 75: The maximum distance between between two iterations is 0.20 pm.
# on 75: Max force: 9.998962013924029e-13
# on 75: The cavity frequency is:  799999938.2869217
# on 76: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.007085427135678394), 'gate_bottom': np.float64(-0.007085427135678394), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 76: Converged after 18381 steps.
# on 76: The maximum distance between between two iterations is 0.20 pm.
# on 76: Max force: 9.993254934670404e-13
# on 76: The cavity frequency is:  799999939.3180282
# on 77: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.006783919597989952), 'gate_bottom': np.float64(-0.006783919597989952), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 77: Converged after 19233 steps.
# on 77: The maximum distance between between two iterations is 0.20 pm.
# on 77: Max force: 9.996538210543805e-13
# on 77: The cavity frequency is:  799999939.1833799
# on 78: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.00648241206030151), 'gate_bottom': np.float64(-0.00648241206030151), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 78: Converged after 19294 steps.
# on 78: The maximum distance between between two iterations is 0.20 pm.
# on 78: Max force: 9.997797860705758e-13
# on 78: The cavity frequency is:  799999939.0469011
# on 79: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.006180904522613068), 'gate_bottom': np.float64(-0.006180904522613068), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 79: Converged after 19358 steps.
# on 79: The maximum distance between between two iterations is 0.20 pm.
# on 79: Max force: 9.99526946543483e-13
# on 79: The cavity frequency is:  799999938.9080306
# on 80: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.005879396984924623), 'gate_bottom': np.float64(-0.005879396984924623), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 80: Converged after 19421 steps.
# on 80: The maximum distance between between two iterations is 0.20 pm.
# on 80: Max force: 9.997443157772068e-13
# on 80: The cavity frequency is:  799999938.766519
# on 81: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.005577889447236181), 'gate_bottom': np.float64(-0.005577889447236181), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 81: Converged after 19490 steps.
# on 81: The maximum distance between between two iterations is 0.20 pm.
# on 81: Max force: 9.998939276556483e-13
# on 81: The cavity frequency is:  799999938.6212112
# on 82: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.005276381909547739), 'gate_bottom': np.float64(-0.005276381909547739), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 82: Converged after 19561 steps.
# on 82: The maximum distance between between two iterations is 0.20 pm.
# on 82: Max force: 9.997816050599794e-13
# on 82: The cavity frequency is:  799999938.4717023
# on 83: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.0049748743718592975), 'gate_bottom': np.float64(-0.0049748743718592975), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 83: Converged after 19425 steps.
# on 83: The maximum distance between between two iterations is 0.20 pm.
# on 83: Max force: 9.998575478675774e-13
# on 83: The cavity frequency is:  799999938.8150847
# on 84: Unloading 5 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(-0.004673366834170856), 'gate_bottom': np.float64(-0.004673366834170856), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 84: Converged after 19963 steps.
# on 84: The maximum distance between between two iterations is 0.20 pm.
# on 84: Max force: 9.996138032875023e-13
# on 84: The cavity frequency is:  799999938.7678821
# ...
# on 168: The maximum distance between between two iterations is 0.54 pm.
# on 168: Max force: 9.96748153098137e-13
# on 168: The cavity frequency is:  799999989.9864504
# on 169: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.02095477386934673), 'gate_bottom': np.float64(0.02095477386934673), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 169: Converged after 3721 steps.
# on 169: The maximum distance between between two iterations is 0.42 pm.
# on 169: Max force: 9.945626630869508e-13
# on 169: The cavity frequency is:  799999989.8960441
# on 170: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.02125628140703517), 'gate_bottom': np.float64(0.02125628140703517), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 170: Converged after 3780 steps.
# on 170: The maximum distance between between two iterations is 0.33 pm.
# on 170: Max force: 9.994790017564537e-13
# on 170: The cavity frequency is:  799999989.7987489
# on 171: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.021557788944723613), 'gate_bottom': np.float64(0.021557788944723613), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 171: Converged after 3413 steps.
# on 171: The maximum distance between between two iterations is 0.84 pm.
# on 171: Max force: 9.984581765820622e-13
# on 171: The cavity frequency is:  799999989.6935683
# on 172: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.021859296482412055), 'gate_bottom': np.float64(0.021859296482412055), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 172: Converged after 3731 steps.
# on 172: The maximum distance between between two iterations is 0.44 pm.
# on 172: Max force: 9.940113946393936e-13
# on 172: The cavity frequency is:  799999989.5789754
# on 173: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.022160804020100497), 'gate_bottom': np.float64(0.022160804020100497), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 173: Converged after 3966 steps.
# on 173: The maximum distance between between two iterations is 0.29 pm.
# on 173: Max force: 9.98460209344909e-13
# on 173: The cavity frequency is:  799999989.4417726
# on 174: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.02246231155778894), 'gate_bottom': np.float64(0.02246231155778894), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 174: Converged after 4081 steps.
# on 174: The maximum distance between between two iterations is 0.36 pm.
# on 174: Max force: 9.977972648678167e-13
# on 174: The cavity frequency is:  799999989.3049349
# on 175: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.02276381909547738), 'gate_bottom': np.float64(0.02276381909547738), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 175: Converged after 4606 steps.
# on 175: The maximum distance between between two iterations is 0.32 pm.
# on 175: Max force: 9.990092772471648e-13
# on 175: The cavity frequency is:  799999989.154186
# on 176: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.023065326633165822), 'gate_bottom': np.float64(0.023065326633165822), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 176: Converged after 5051 steps.
# on 176: The maximum distance between between two iterations is 0.30 pm.
# on 176: Max force: 9.961843425165816e-13
# on 176: The cavity frequency is:  799999988.9869199
# on 177: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.023366834170854264), 'gate_bottom': np.float64(0.023366834170854264), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 177: Converged after 5492 steps.
# on 177: The maximum distance between between two iterations is 0.29 pm.
# on 177: Max force: 9.966837084540713e-13
# on 177: The cavity frequency is:  799999988.7999322
# on 178: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.023668341708542706), 'gate_bottom': np.float64(0.023668341708542706), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 178: Converged after 6062 steps.
# on 178: The maximum distance between between two iterations is 0.28 pm.
# on 178: Max force: 9.969677089438633e-13
# on 178: The cavity frequency is:  799999988.5604705
# on 179: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.023969849246231148), 'gate_bottom': np.float64(0.023969849246231148), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 179: Converged after 6511 steps.
# on 179: The maximum distance between between two iterations is 0.27 pm.
# on 179: Max force: 9.994021743509052e-13
# on 179: The cavity frequency is:  799999988.3173237
# on 180: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.02427135678391959), 'gate_bottom': np.float64(0.02427135678391959), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 180: Converged after 6983 steps.
# on 180: The maximum distance between between two iterations is 0.27 pm.
# on 180: Max force: 9.991909640794106e-13
# on 180: The cavity frequency is:  799999988.0336382
# on 181: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.02457286432160803), 'gate_bottom': np.float64(0.02457286432160803), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 181: Converged after 7694 steps.
# on 181: The maximum distance between between two iterations is 0.26 pm.
# on 181: Max force: 9.99013509916935e-13
# on 181: The cavity frequency is:  799999987.7057625
# on 182: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.02487437185929648), 'gate_bottom': np.float64(0.02487437185929648), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 182: Converged after 14493 steps.
# on 182: The maximum distance between between two iterations is 0.23 pm.
# on 182: Max force: 9.991283229648928e-13
# on 182: The cavity frequency is:  799999983.8107792
# on 183: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.025175879396984922), 'gate_bottom': np.float64(0.025175879396984922), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 183: Converged after 14743 steps.
# on 183: The maximum distance between between two iterations is 0.22 pm.
# on 183: Max force: 9.986940481265805e-13
# on 183: The cavity frequency is:  799999983.091282
# on 184: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.025477386934673364), 'gate_bottom': np.float64(0.025477386934673364), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 184: Converged after 11020 steps.
# on 184: The maximum distance between between two iterations is 0.19 pm.
# on 184: Max force: 9.988541782579574e-13
# on 184: The cavity frequency is:  799999986.243627
# on 185: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.025778894472361806), 'gate_bottom': np.float64(0.025778894472361806), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 185: Converged after 20508 steps.
# on 185: The maximum distance between between two iterations is 0.22 pm.
# on 185: Max force: 9.996760287345195e-13
# on 185: The cavity frequency is:  799999980.9417243
# on 186: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.026080402010050248), 'gate_bottom': np.float64(0.026080402010050248), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 186: Converged after 23036 steps.
# on 186: The maximum distance between between two iterations is 0.21 pm.
# on 186: Max force: 9.995255498829181e-13
# on 186: The cavity frequency is:  799999979.299173
# on 187: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.02638190954773869), 'gate_bottom': np.float64(0.02638190954773869), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 187: Converged after 29108 steps.
# on 187: The maximum distance between between two iterations is 0.20 pm.
# on 187: Max force: 9.995891108172116e-13
# on 187: The cavity frequency is:  799999976.7641703
# on 188: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.02668341708542713), 'gate_bottom': np.float64(0.02668341708542713), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 188: Converged after 41849 steps.
# on 188: The maximum distance between between two iterations is 0.19 pm.
# on 188: Max force: 9.997892265189987e-13
# on 188: The cavity frequency is:  799999972.0753738
# on 189: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.026984924623115573), 'gate_bottom': np.float64(0.026984924623115573), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 189: Converged after 44805 steps.
# on 189: The maximum distance between between two iterations is 0.16 pm.
# on 189: Max force: 9.99872661111567e-13
# on 189: The cavity frequency is:  799999972.4059343
# on 190: Unloading 2 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.027286432160804015), 'gate_bottom': np.float64(0.027286432160804015), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 190: Converged after 111064 steps.
# on 190: The maximum distance between between two iterations is 0.20 pm.
# on 190: Max force: 9.999638908020357e-13
# on 190: The cavity frequency is:  799999968.3677053
# on 191: Unloading 1 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.027587939698492457), 'gate_bottom': np.float64(0.027587939698492457), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 191: Converged after 2061126 steps.
# on 191: The maximum distance between between two iterations is 0.18 pm.
# on 191: Max force: 9.999966290225507e-13
# on 191: The cavity frequency is:  799999999.9989898
# on 192: Unloading 1 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.0278894472361809), 'gate_bottom': np.float64(0.0278894472361809), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 192: Converged after 1289845 steps.
# on 192: The maximum distance between between two iterations is 0.18 pm.
# on 192: Max force: 9.999921529533429e-13
# on 192: The cavity frequency is:  799999999.9990106
# on 193: Unloading 1 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.02819095477386934), 'gate_bottom': np.float64(0.02819095477386934), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 193: Not converged after 4000000 steps.
# on 193: The maximum distance between between two iterations is 0.00 pm.
# on 193: Max force: 1.2642665873352758e-12
# on 193: The cavity frequency is:  799999999.9990098
# on 194: Unloading 1 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.028492462311557783), 'gate_bottom': np.float64(0.028492462311557783), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 194: Converged after 1305617 steps.
# on 194: The maximum distance between between two iterations is 0.18 pm.
# on 194: Max force: 9.99994572963856e-13
# on 194: The cavity frequency is:  799999999.9990082
# on 195: Unloading 1 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.028793969849246225), 'gate_bottom': np.float64(0.028793969849246225), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 195: Converged after 729657 steps.
# on 195: The maximum distance between between two iterations is 0.18 pm.
# on 195: Max force: 9.999964877676462e-13
# on 195: The cavity frequency is:  799999999.999007
# on 196: Unloading 1 electrons with voltages: {'half_donut_top': 0.05, 'half_donut_bottom': 0.05, 'gate_top': np.float64(0.029095477386934666), 'gate_bottom': np.float64(0.029095477386934666), 'reservoir': 0.05, 'center': 0.0, 'guard': 0.0}
# on 196: During the convergence, no electrons left after 16698 steps.
# on 197: During the voltage sweep, no electrons left after 197 steps.
# |███████████████████████████████████████▍⚠︎ (!) 197/200 [98%] in 22:15.1 (0.15/s)

# %%
f0_list = [0.120945e9, 0.400e9, 0.600e9, 0.800e9]

# %%
print(electron_initial_positions)
print(equilibrium_positions)
print(r_cur)
print((electron_initial_positions / L0).astype(np.float64))  
print(N)
# Out:
# []
# []
# []
# []
# 0

# %% [markdown]
# ### Animates the voltage sweep

# %%
fig, ax = plt.subplots(figsize=(7, 4.))
print(len(list_of_voltages))
print(len(electron_configurations))
anim = f.animate_voltage_sweep(fig, ax,  list_of_voltages=list_of_voltages, list_of_electron_positions=electron_configurations,
                            dxdy=(10, 8), frame_interval_ms=200 )
ax.set_xlim(-5, 1.9)
f.show_animation(anim)
# Out:
# 196
# 196
# <video width="700" height="400" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Plot the number of electrons and the frequency shifts

# %%
# %matplotlib inline


fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(14, 5), sharex=True)

# ==== Left subplot ====

voltages_unload=[d['gate_top'] for d in list_of_voltages]
ax1.step(voltages_unload, num_electrons, label="Number of electrons", color='tab:blue')
ax1.set_xlabel("Top and bottom gate voltage [V]")
ax1.set_ylabel("Number of electrons")

ax2 = ax1.twinx()
ax2.plot(voltages_unload, cavity_freqs - f0*np.ones(len(cavity_freqs)), 'r--', label="Cavity frequency shift")
ax2.set_ylabel("Cavity frequency shift [Hz]")
ax2.spines["right"].set_position(("axes", 1.1))

# Legend for left subplot at bottom left
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='lower left', frameon=False)

  
# ==== Right subplot ====
ax3.step(voltages_unload, num_electrons, label="Number of electrons", color='tab:blue')
ax3.set_xlabel("Top and bottom gate voltage [V]")
ax3.set_ylabel("Number of electrons")

ax4 = ax3.twinx()
ax4.plot(voltages_unload, electron_modef, 'g--', label="First electron mode frequency")
ax4.set_ylabel("First electron mode frequency [Hz]")
ax4.spines["right"].set_position(("axes", 1.1))

# Legend for right subplot at bottom left
lines3, labels3 = ax3.get_legend_handles_labels()
lines4, labels4 = ax4.get_legend_handles_labels()
ax3.legend(lines3 + lines4, labels3 + labels4, loc='lower left', frameon=False)

plt.tight_layout()
plt.show()
